# %%
pip install -q torch transformers langchain_chroma bitsandbytes langchain faiss-gpu langchain_huggingface langchain-community sentence-transformers  pacmap tqdm matplotlib datasets
# Out:
# ERROR: Could not find a version that satisfies the requirement faiss-gpu (from versions: none)
# ERROR: No matching distribution found for faiss-gpu

# %%
pip install -q sentence_transformers

# %%
# !python --version
# Out:
# Python 3.12.12

# %%
from tqdm.notebook import tqdm
import pandas as pd
import os
import csv
import sys
import numpy as np
import time
import random
from typing import Optional, List, Tuple
import matplotlib.pyplot as plt
import textwrap
import torch

import random
import torch
from torch.utils.data import Dataset, DataLoader, random_split
from sklearn.model_selection import train_test_split
from transformers import BertTokenizer, BertModel
from torch import nn
from torch.optim import Adam
from tqdm import tqdm
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Processing dataset

# %%
import json
from huggingface_hub import hf_hub_download

filepath = hf_hub_download(
    repo_id='McAuley-Lab/Amazon-C4',
    filename='sampled_item_metadata_1M.jsonl',
    repo_type='dataset'
)

item_pool = []
with open(filepath, 'r') as file:
    for line in file:
        item_pool.append(json.loads(line.strip()))
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# sampled_item_metadata_1M.jsonl:   0%|          | 0.00/643M [00:00<?, ?B/s]

# %%
from datasets import load_dataset

dataset = load_dataset('McAuley-Lab/Amazon-C4')['test']
# Out:
# README.md: 0.00B [00:00, ?B/s]
# test.csv:   0%|          | 0.00/12.5M [00:00<?, ?B/s]
# Generating test split:   0%|          | 0/21223 [00:00<?, ? examples/s]

# %%
item_metadata_map = {item['item_id']: {'metadata': item['metadata'], 'category': item['category']} for item in item_pool}

# %%
# new_list = []
# for data in dataset:
#     item_id = data['item_id']
#     item_info = item_metadata_map.get(item_id, {'metadata': None, 'category': None})  # 找到 metadata 和 category
#     new_entry = {
#         'query': data['query'],
#         'item_id': item_id,
#         'metadata': item_info['metadata'],
#         'category': item_info['category']
#     }
#     new_list.append(new_entry)

# %%
new_list = []
for data in dataset:
    item_id = data['item_id']
    item_info = item_metadata_map.get(item_id, {'metadata': None, 'category': None})

    metadata = item_info['metadata']
    if metadata is None or len(metadata.split()) < 10:
        continue

    new_entry = {
        'query': data['query'],
        'item_id': item_id,
        'metadata': metadata,
        'category': item_info['category']
    }
    new_list.append(new_entry)

# %%
print(len(new_list))
# Out:
# 20250

# %%
queries = []
passages = []


limit = max(1, len(new_list) // 20)

for idx, entry in enumerate(new_list):
    if idx < limit:
        queries.append(f"query: {entry['query']}")
        passages.append(f"passage: {entry['metadata']}")

input_texts = queries + passages

# print(input_texts)

# %%
RANDOM_SEED = 42
random.seed(RANDOM_SEED)

random.shuffle(new_list)
split_idx = int(0.9 * len(new_list))
train_pool = new_list[:split_idx]
test_pool = new_list[split_idx:]

def prepare_dataset(pool):
    # 修改：使用 query 而不是 metadata 来训练分类器
    queries = [item['query'] for item in pool if item['query'] and item['category']]
    categories = [item['category'] for item in pool if item['query'] and item['category']]
    return queries, categories

train_queries, train_categories = prepare_dataset(train_pool)
test_queries, test_categories = prepare_dataset(test_pool)

category_to_idx = {category: idx for idx, category in enumerate(set(train_categories))}
idx_to_category = {idx: category for category, idx in category_to_idx.items()}
train_labels = [category_to_idx[cat] for cat in train_categories]
test_labels = [category_to_idx[cat] for cat in test_categories]

print(f"Training samples: {len(train_queries)}")
print(f"Test samples: {len(test_queries)}")
print(f"Number of categories: {len(category_to_idx)}")
# Out:
# Training samples: 18225
# Test samples: 2025
# Number of categories: 30

# %%
class QueryDataset(Dataset):
    def __init__(self, queries, labels, tokenizer, max_len=128):
        self.queries = queries
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len

    def __len__(self):
        return len(self.queries)

    def __getitem__(self, idx):
        query = self.queries[idx]
        label = self.labels[idx]
        encoding = self.tokenizer(
            query,
            max_length=self.max_len,
            truncation=True,
            padding="max_length",
            return_tensors="pt",
        )
        return {
            "input_ids": encoding["input_ids"].squeeze(0),
            "attention_mask": encoding["attention_mask"].squeeze(0),
            "label": torch.tensor(label, dtype=torch.long),
        }

tokenizer = BertTokenizer.from_pretrained("bert-large-uncased")

train_dataset = QueryDataset(train_queries, train_labels, tokenizer)
test_dataset = QueryDataset(test_queries, test_labels, tokenizer)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=32, shuffle=False)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
class QueryClassifier(nn.Module):
    def __init__(self, num_categories):
        super(QueryClassifier, self).__init__()
        self.bert = BertModel.from_pretrained("bert-large-uncased")
        self.classifier = nn.Sequential(
            nn.Linear(self.bert.config.hidden_size, 512),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(512, num_categories)
        )

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        cls_token = outputs.last_hidden_state[:, 0, :]  # [CLS] token embedding
        logits = self.classifier(cls_token)
        return logits

num_categories = len(category_to_idx)
model = QueryClassifier(num_categories).to(device)
# Out:
# model.safetensors:   0%|          | 0.00/1.34G [00:00<?, ?B/s]

# %%
def train_model(model, train_loader, test_loader, num_epochs=3, lr=1e-5):
    optimizer = Adam(model.parameters(), lr=lr)
    criterion = nn.CrossEntropyLoss()
    model.train()

    for epoch in range(num_epochs):
        total_loss = 0
        for batch in tqdm(train_loader, desc=f"Training Epoch {epoch+1}"):
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)

            optimizer.zero_grad()
            outputs = model(input_ids, attention_mask)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            total_loss += loss.item()

        avg_loss = total_loss / len(train_loader)
        print(f"Epoch {epoch+1}, Loss: {avg_loss:.4f}")

    return model

model = train_model(model, train_loader, test_loader, num_epochs=4)
classifier_model = model
# Out:
# Training Epoch 1: 100%|██████████| 570/570 [04:49<00:00,  1.97it/s]
# Epoch 1, Loss: 1.7836
# Training Epoch 2: 100%|██████████| 570/570 [04:48<00:00,  1.97it/s]
# Epoch 2, Loss: 1.0780
# Training Epoch 3: 100%|██████████| 570/570 [04:48<00:00,  1.97it/s]
# Epoch 3, Loss: 0.8272
# Training Epoch 4: 100%|██████████| 570/570 [04:48<00:00,  1.97it/s]
# Epoch 4, Loss: 0.6277

# %%
def evaluate_model(model, test_loader, top_k=3):
    model.eval()
    all_labels = []
    all_predictions = []

    with torch.no_grad():
        for batch in tqdm(test_loader, desc="Evaluating"):
            input_ids = batch["input_ids"].to(device)
            attention_mask = batch["attention_mask"].to(device)
            labels = batch["label"].to(device)

            outputs = model(input_ids, attention_mask)
            _, top_preds = torch.topk(outputs, k=top_k, dim=-1)

            all_labels.extend(labels.cpu().numpy())
            all_predictions.extend(top_preds.cpu().numpy())

    top_k_accuracy = 0
    for label, preds in zip(all_labels, all_predictions):
        if label in preds:
            top_k_accuracy += 1

    top_k_accuracy /= len(all_labels)
    print(f"Top-{top_k} Accuracy: {top_k_accuracy:.4f}")

evaluate_model(classifier_model, test_loader, top_k=4)
# Out:
# Evaluating: 100%|██████████| 64/64 [00:12<00:00,  5.27it/s]
# Top-4 Accuracy: 0.9022

# %%
from torch.nn.functional import softmax

result_list = []

model.eval()

print("Running inference: Using trained query classifier to predict categories...")

with torch.no_grad():
    for batch_idx, batch in enumerate(test_loader):
        input_ids = batch["input_ids"].to(device)
        attention_mask = batch["attention_mask"].to(device)

        # 现在 test_loader 中是真实的 query，直接用来预测类别
        logits = model(input_ids, attention_mask)
        probabilities = softmax(logits, dim=-1)

        # 获取 top-2 预测类别 (categories # changed to 4)
        top2_indices = torch.topk(probabilities, 4, dim=-1).indices.cpu().numpy()

        for i, top2 in enumerate(top2_indices):
            top2_categories = [idx_to_category[idx] for idx in top2]

            # 根据预测的类别筛选候选商品
            matched_items = [
                {
                    "item_id": item["item_id"],
                    "metadata": item["metadata"],
                    "category": item["category"],
                }
                for item in new_list
                if item["category"] in top2_categories
            ]

            # 获取对应的真实 query 和 ground truth
            test_idx = batch_idx * test_loader.batch_size + i
            result_list.append({
                "query": test_pool[test_idx]['query'],
                "real_category": test_pool[test_idx]['category'],
                "real_item_id": test_pool[test_idx]['item_id'],
                "top2_categories": top2_categories,
                "matched_items": matched_items
            })

print(f"✓ Processed {len(result_list)} test queries")
print(f"  Average candidate pool size: {sum(len(r['matched_items']) for r in result_list) / len(result_list):.0f}")
# Out:
# Running inference: Using trained query classifier to predict categories...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1884010971.py in <cell line: 0>()
#      24             # 根据预测的类别筛选候选商品
#      25             matched_items = [
# ---> 26                 {
#      27                     "item_id": item["item_id"],
#      28                     "metadata": item["metadata"],
#
# KeyboardInterrupt:

# %% [markdown]
# ## ✅ 改进说明：Query-Based 分类器
#
# **主要修改**:
# - **Cell 12**: `prepare_dataset()` 现在使用 `item['query']` 而不是 `item['metadata']`
# - **Cell 18**: 推理时直接用 query 预测类别，无需额外添加
#
# **新的训练流程**:
# ```
# 用户 query → BERT QueryClassifier → Top-2 categories → 候选商品池
# ```
#
# **优势**:
# 1. ✅ Query 真正参与训练
# 2. ✅ 推理流程符合实际应用 (用户只提供 query)
# 3. ✅ 代码更简洁，逻辑更清晰
#
# **下一步**: 重新运行 Cell 12-18 来训练新的 query 分类器

# %%
# Save the trained QueryClassifier model
torch.save(model.state_dict(), 'query_classifier.pth')
classifier_model = model  # Keep a reference before it gets overwritten
print("✓ Saved query_classifier.pth")
print(f"  Model has {num_categories} output categories")
# Out:
# ✓ Saved query_classifier.pth
#   Model has 30 output categories

# %%
# -*- coding: utf-8 -*-

import torch
import torch.nn.functional as F
from torch import Tensor
from transformers import AutoTokenizer, AutoModel
import gc

def average_pool(last_hidden_states: Tensor,
                 attention_mask: Tensor) -> Tensor:
    last_hidden = last_hidden_states.masked_fill(~attention_mask[..., None].bool(), 0.0)
    return last_hidden.sum(dim=1) / attention_mask.sum(dim=1)[..., None]

tokenizer = AutoTokenizer.from_pretrained('intfloat/multilingual-e5-base')
model = AutoModel.from_pretrained('intfloat/multilingual-e5-base').to(device)
# Out:
# tokenizer_config.json:   0%|          | 0.00/418 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.1M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/280 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/694 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.11G [00:00<?, ?B/s]

# %%
for result in result_list:
    query = []
    passages = []
    query.append(f"query: {result['query']}")
    for matched_item in result['matched_items']:
        passages.append(f"passage: {matched_item['metadata']}")
    # print(query)
    input_texts = query + passages
    batch_dict = tokenizer(
        input_texts,
        max_length=128,
        padding=True,
        truncation=True,
        return_tensors='pt'
    )

    batch_dict = {key: value.to(device) for key, value in batch_dict.items()}

    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])

    embeddings = F.normalize(embeddings, p=2, dim=1)

    scores = (embeddings[:1] @ embeddings[1:].T) * 100
    print(scores)
    break
# Out:
# tensor([[73.9798, 75.9833, 77.4119,  ..., 79.6367, 78.5389, 77.7805]],
#        device='cuda:0')

# %%
import torch
import torch.nn.functional as F

for result in result_list:
    query = []
    passages = []
    query.append(f"query: {result['query']}")

    for matched_item in result['matched_items']:
        passages.append(f"passage: {matched_item['metadata']}")

    # Combine query and passages into input_texts
    input_texts = query + passages

    # Tokenize inputs
    batch_dict = tokenizer(
        input_texts,
        max_length=128,
        padding=True,
        truncation=True,
        return_tensors='pt'
    )
    batch_dict = {key: value.to(device) for key, value in batch_dict.items()}

    # Get embeddings
    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])
    embeddings = F.normalize(embeddings, p=2, dim=1)

    # Compute scores
    scores = (embeddings[:1] @ embeddings[1:].T) * 100  # Compute similarity scores
    scores = scores.squeeze(0)  # Remove extra dimension for easier processing

    # Get top-10 scores and corresponding indices
    top_scores, top_indices = torch.topk(scores, k=1000)

    # Map top scores to matched_items and check their IDs
    top_matched_items = [result['matched_items'][idx] for idx in top_indices]
    print(result['real_item_id'])
    for i, matched_item in enumerate(top_matched_items):
        item_id = matched_item['item_id']
        is_real_item = item_id == result['real_item_id']
        print(f"Rank {i+1}: Score = {top_scores[i].item():.2f}, Item ID = {item_id}, Is Real Item: {is_real_item}")

    break  # Break after processing the first result (for debugging)
# Out:
# B0BP6WWSBD
# Rank 1: Score = 84.28, Item ID = B09D2TRSHM, Is Real Item: False
# Rank 2: Score = 83.96, Item ID = B0B6BD13Q9, Is Real Item: False
# Rank 3: Score = 83.87, Item ID = B0BP6WWSBD, Is Real Item: True
# Rank 4: Score = 83.87, Item ID = B0BP6WWSBD, Is Real Item: True
# Rank 5: Score = 83.67, Item ID = B0B464RB6B, Is Real Item: False
# Rank 6: Score = 83.42, Item ID = B0C8V52BLR, Is Real Item: False
# Rank 7: Score = 83.36, Item ID = B0C5H87577, Is Real Item: False
# Rank 8: Score = 83.31, Item ID = B0B451WX1G, Is Real Item: False
# Rank 9: Score = 83.30, Item ID = B09F35NTYT, Is Real Item: False
# Rank 10: Score = 83.30, Item ID = B09F35NTYT, Is Real Item: False
# Rank 11: Score = 83.04, Item ID = B0BYTJ6LDR, Is Real Item: False
# Rank 12: Score = 83.02, Item ID = B0923LNLK7, Is Real Item: False
# Rank 13: Score = 82.97, Item ID = B07JLTMQJT, Is Real Item: False
# Rank 14: Score = 82.81, Item ID = B085C2HMQP, Is Real Item: False
# Rank 15: Score = 82.76, Item ID = B08R2N5SDX, Is Real Item: False
# Rank 16: Score = 82.76, Item ID = B0B9MZZ96T, Is Real Item: False
# Rank 17: Score = 82.74, Item ID = B09LB1BHLB, Is Real Item: False
# Rank 18: Score = 82.69, Item ID = B07BFH9WZ7, Is Real Item: False
# Rank 19: Score = 82.47, Item ID = B0BZH7NHG4, Is Real Item: False
# Rank 20: Score = 82.31, Item ID = B0BK8DQ4H1, Is Real Item: False
# Rank 21: Score = 82.17, Item ID = B0B3LLD5J4, Is Real Item: False
# Rank 22: Score = 82.04, Item ID = B0BFQ4YG6Z, Is Real Item: False
# Rank 23: Score = 81.84, Item ID = B09WV6GTB3, Is Real Item: False
# Rank 24: Score = 81.70, Item ID = B0BTVP9DD3, Is Real Item: False
# Rank 25: Score = 81.63, Item ID = B0BPMQ26X1, Is Real Item: False
# Rank 26: Score = 81.58, Item ID = B0BBQNYLNP, Is Real Item: False
# Rank 27: Score = 81.53, Item ID = B08N4Y4KLV, Is Real Item: False
# Rank 28: Score = 81.45, Item ID = B09ZTSZKD1, Is Real Item: False
# Rank 29: Score = 81.25, Item ID = B0BY9NPPJT, Is Real Item: False
# Rank 30: Score = 81.19, Item ID = B097RWW2PX, Is Real Item: False
# Rank 31: Score = 81.18, Item ID = B09FCDYBQM, Is Real Item: False
# Rank 32: Score = 81.07, Item ID = B0B6BMNQ53, Is Real Item: False
# Rank 33: Score = 81.04, Item ID = B07D3PVBJ4, Is Real Item: False
# Rank 34: Score = 81.01, Item ID = B09784ZP2R, Is Real Item: False
# Rank 35: Score = 81.00, Item ID = B08XN9YT2H, Is Real Item: False
# Rank 36: Score = 80.98, Item ID = B09ZQKV4N6, Is Real Item: False
# Rank 37: Score = 80.95, Item ID = B08CHDB7ZZ, Is Real Item: False
# Rank 38: Score = 80.93, Item ID = B09CPNS1VY, Is Real Item: False
# Rank 39: Score = 80.84, Item ID = B07Y9WY7H7, Is Real Item: False
# Rank 40: Score = 80.82, Item ID = B09GPNY29D, Is Real Item: False
# Rank 41: Score = 80.82, Item ID = B09P9VWZJ1, Is Real Item: False
# Rank 42: Score = 80.81, Item ID = B0BB1NYJGH, Is Real Item: False
# Rank 43: Score = 80.80, Item ID = B07RYPDSD8, Is Real Item: False
# Rank 44: Score = 80.80, Item ID = B07RYPDSD8, Is Real Item: False
# Rank 45: Score = 80.80, Item ID = B07RYPDSD8, Is Real Item: False
# Rank 46: Score = 80.76, Item ID = B0BRN9Z14V, Is Real Item: False
# Rank 47: Score = 80.75, Item ID = B0C7QDD8GQ, Is Real Item: False
# Rank 48: Score = 80.74, Item ID = B0C3QPNZ2L, Is Real Item: False
# Rank 49: Score = 80.69, Item ID = B09MLHLXDG, Is Real Item: False
# Rank 50: Score = 80.68, Item ID = B0855C9BGS, Is Real Item: False
# Rank 51: Score = 80.68, Item ID = B07PLNZQBQ, Is Real Item: False
# Rank 52: Score = 80.66, Item ID = B0C1BD44L9, Is Real Item: False
# Rank 53: Score = 80.59, Item ID = B09PYLNX9Z, Is Real Item: False
# Rank 54: Score = 80.56, Item ID = B09HGG2MC3, Is Real Item: False
# Rank 55: Score = 80.54, Item ID = B0BJK7RLSF, Is Real Item: False
# Rank 56: Score = 80.54, Item ID = B0C6DMWBWR, Is Real Item: False
# Rank 57: Score = 80.53, Item ID = B0B8MS1GDG, Is Real Item: False
# Rank 58: Score = 80.51, Item ID = B09SHNYJTM, Is Real Item: False
# Rank 59: Score = 80.50, Item ID = B0BP8H9FZZ, Is Real Item: False
# Rank 60: Score = 80.48, Item ID = B0B1Q899WQ, Is Real Item: False
# Rank 61: Score = 80.46, Item ID = B0B3STBY2J, Is Real Item: False
# Rank 62: Score = 80.44, Item ID = B09BTW379L, Is Real Item: False
# Rank 63: Score = 80.44, Item ID = B088S9FSHP, Is Real Item: False
# Rank 64: Score = 80.42, Item ID = B0BXKS3DTZ, Is Real Item: False
# Rank 65: Score = 80.42, Item ID = B0B4689MYZ, Is Real Item: False
# Rank 66: Score = 80.41, Item ID = B0C7H753N4, Is Real Item: False
# Rank 67: Score = 80.41, Item ID = B0C66WW1FK, Is Real Item: False
# Rank 68: Score = 80.41, Item ID = B0BKRND182, Is Real Item: False
# Rank 69: Score = 80.40, Item ID = B0B153K3WR, Is Real Item: False
# Rank 70: Score = 80.36, Item ID = B09W318F3C, Is Real Item: False
# Rank 71: Score = 80.36, Item ID = B092DT5ZNT, Is Real Item: False
# Rank 72: Score = 80.35, Item ID = B0C7QDXT6R, Is Real Item: False
# Rank 73: Score = 80.33, Item ID = B09VKHRPDH, Is Real Item: False
# Rank 74: Score = 80.32, Item ID = B0BVR4VNGX, Is Real Item: False
# Rank 75: Score = 80.31, Item ID = B09BG43VQ8, Is Real Item: False
# Rank 76: Score = 80.28, Item ID = B0C54BTFGQ, Is Real Item: False
# Rank 77: Score = 80.23, Item ID = B0C542NGGP, Is Real Item: False
# Rank 78: Score = 80.23, Item ID = B0BXHLWCR5, Is Real Item: False
# Rank 79: Score = 80.22, Item ID = B09QPNP762, Is Real Item: False
# Rank 80: Score = 80.22, Item ID = B0C6ZFGM7D, Is Real Item: False
# Rank 81: Score = 80.22, Item ID = B01LLWKXV6, Is Real Item: False
# Rank 82: Score = 80.22, Item ID = B0BD7T34KZ, Is Real Item: False
# Rank 83: Score = 80.22, Item ID = B0CGYPPPT3, Is Real Item: False
# Rank 84: Score = 80.20, Item ID = B0BHKMCJ24, Is Real Item: False
# Rank 85: Score = 80.20, Item ID = B08HYH6TJ6, Is Real Item: False
# Rank 86: Score = 80.19, Item ID = B00WW8CB14, Is Real Item: False
# Rank 87: Score = 80.17, Item ID = B07X6GHLLT, Is Real Item: False
# Rank 88: Score = 80.17, Item ID = B0BNXGRCKM, Is Real Item: False
# Rank 89: Score = 80.15, Item ID = B087BLS9RH, Is Real Item: False
# Rank 90: Score = 80.12, Item ID = B00204O7EY, Is Real Item: False
# Rank 91: Score = 80.12, Item ID = B0C22RJ6FM, Is Real Item: False
# Rank 92: Score = 80.11, Item ID = B07WFJHPFY, Is Real Item: False
# Rank 93: Score = 80.11, Item ID = B0BJZFNC8B, Is Real Item: False
# Rank 94: Score = 80.10, Item ID = B09ZVKVXDT, Is Real Item: False
# Rank 95: Score = 80.10, Item ID = B082QJ7H1R, Is Real Item: False
# Rank 96: Score = 80.10, Item ID = B07C3TJ8MZ, Is Real Item: False
# Rank 97: Score = 80.08, Item ID = B07PGHXXVF, Is Real Item: False
# Rank 98: Score = 80.06, Item ID = B095PCLG59, Is Real Item: False
# Rank 99: Score = 80.04, Item ID = B0C4T6RPWP, Is Real Item: False
# Rank 100: Score = 80.04, Item ID = B0BPCC4RQ9, Is Real Item: False
# Rank 101: Score = 80.04, Item ID = B0C4V5WL3V, Is Real Item: False
# Rank 102: Score = 80.04, Item ID = B09WSQBGPJ, Is Real Item: False
# Rank 103: Score = 80.00, Item ID = B0B4NS25CX, Is Real Item: False
# Rank 104: Score = 80.00, Item ID = B09ZK74QVQ, Is Real Item: False
# Rank 105: Score = 80.00, Item ID = B0BLSLSBF6, Is Real Item: False
# Rank 106: Score = 79.98, Item ID = B0B7FP7DKG, Is Real Item: False
# Rank 107: Score = 79.98, Item ID = B0BD481G3B, Is Real Item: False
# Rank 108: Score = 79.97, Item ID = B09BKHDKNV, Is Real Item: False
# Rank 109: Score = 79.97, Item ID = B0B1J7K4J9, Is Real Item: False
# Rank 110: Score = 79.97, Item ID = B095HN6M3J, Is Real Item: False
# Rank 111: Score = 79.97, Item ID = B074HW532B, Is Real Item: False
# Rank 112: Score = 79.96, Item ID = B0C73GJQMY, Is Real Item: False
# Rank 113: Score = 79.95, Item ID = B09S361GZV, Is Real Item: False
# Rank 114: Score = 79.95, Item ID = B002Y35O5W, Is Real Item: False
# Rank 115: Score = 79.93, Item ID = B09N7535Z8, Is Real Item: False
# Rank 116: Score = 79.93, Item ID = B089D58W54, Is Real Item: False
# Rank 117: Score = 79.93, Item ID = B0BG23DP2X, Is Real Item: False
# Rank 118: Score = 79.90, Item ID = B0B7C11QK1, Is Real Item: False
# Rank 119: Score = 79.88, Item ID = B07RS51G64, Is Real Item: False
# Rank 120: Score = 79.88, Item ID = B08JHMBZWY, Is Real Item: False
# Rank 121: Score = 79.87, Item ID = B09FSNP1X6, Is Real Item: False
# Rank 122: Score = 79.86, Item ID = B09DPBBZF6, Is Real Item: False
# Rank 123: Score = 79.86, Item ID = B09Y5MHBQ8, Is Real Item: False
# Rank 124: Score = 79.85, Item ID = B07HPF1M83, Is Real Item: False
# Rank 125: Score = 79.85, Item ID = B0C5SDR15L, Is Real Item: False
# Rank 126: Score = 79.85, Item ID = B0C5SDR15L, Is Real Item: False
# Rank 127: Score = 79.84, Item ID = B08BZ52P9G, Is Real Item: False
# Rank 128: Score = 79.83, Item ID = B08NK5HXQ3, Is Real Item: False
# Rank 129: Score = 79.83, Item ID = B01F9KLIP6, Is Real Item: False
# Rank 130: Score = 79.82, Item ID = B0C1CGCDK1, Is Real Item: False
# Rank 131: Score = 79.81, Item ID = B085L9YD9N, Is Real Item: False
# Rank 132: Score = 79.81, Item ID = B093DV9YGQ, Is Real Item: False
# Rank 133: Score = 79.80, Item ID = B00652G4TS, Is Real Item: False
# Rank 134: Score = 79.80, Item ID = B08CFV58K2, Is Real Item: False
# Rank 135: Score = 79.80, Item ID = B0BSQNHHSH, Is Real Item: False
# Rank 136: Score = 79.80, Item ID = B095YM1RG2, Is Real Item: False
# Rank 137: Score = 79.79, Item ID = B09XWSRLT4, Is Real Item: False
# Rank 138: Score = 79.79, Item ID = B0BRBZK4XD, Is Real Item: False
# Rank 139: Score = 79.78, Item ID = B0C32ZZVYK, Is Real Item: False
# Rank 140: Score = 79.76, Item ID = B0BFQ6YND8, Is Real Item: False
# Rank 141: Score = 79.75, Item ID = B09QFND19V, Is Real Item: False
# Rank 142: Score = 79.74, Item ID = B0BZBVH9ZF, Is Real Item: False
# Rank 143: Score = 79.73, Item ID = B0C1HPMDS1, Is Real Item: False
# Rank 144: Score = 79.73, Item ID = B0C1HPMDS1, Is Real Item: False
# Rank 145: Score = 79.73, Item ID = B09PV9JC8R, Is Real Item: False
# Rank 146: Score = 79.72, Item ID = B07PQXDQJB, Is Real Item: False
# Rank 147: Score = 79.72, Item ID = B0B8SMMLHP, Is Real Item: False
# Rank 148: Score = 79.71, Item ID = B08V6MJ2NR, Is Real Item: False
# Rank 149: Score = 79.70, Item ID = B0BTT784FZ, Is Real Item: False
# Rank 150: Score = 79.69, Item ID = B0C2Z4KLT1, Is Real Item: False
# Rank 151: Score = 79.69, Item ID = B0B93P9BNY, Is Real Item: False
# Rank 152: Score = 79.69, Item ID = B06Y2G7WLK, Is Real Item: False
# Rank 153: Score = 79.69, Item ID = B0BM48Q1YW, Is Real Item: False
# Rank 154: Score = 79.69, Item ID = B094VDLDVY, Is Real Item: False
# Rank 155: Score = 79.68, Item ID = B0BN48GMPC, Is Real Item: False
# Rank 156: Score = 79.68, Item ID = B09XV3CS8M, Is Real Item: False
# Rank 157: Score = 79.68, Item ID = B0B1DJZQVL, Is Real Item: False
# Rank 158: Score = 79.67, Item ID = B000TQ16HG, Is Real Item: False
# Rank 159: Score = 79.66, Item ID = B09W211J91, Is Real Item: False
# Rank 160: Score = 79.66, Item ID = B094D3M28L, Is Real Item: False
# Rank 161: Score = 79.66, Item ID = B0012Q4IPY, Is Real Item: False
# Rank 162: Score = 79.66, Item ID = B0811Q41XY, Is Real Item: False
# Rank 163: Score = 79.66, Item ID = B09M7PS1QM, Is Real Item: False
# Rank 164: Score = 79.66, Item ID = B08FCYPXDW, Is Real Item: False
# Rank 165: Score = 79.66, Item ID = B0C6GM6K8S, Is Real Item: False
# Rank 166: Score = 79.66, Item ID = B0B4JSZNB6, Is Real Item: False
# Rank 167: Score = 79.65, Item ID = B08PKYPJFB, Is Real Item: False
# Rank 168: Score = 79.64, Item ID = B086MN8MZW, Is Real Item: False
# Rank 169: Score = 79.64, Item ID = B09JFX785L, Is Real Item: False
# Rank 170: Score = 79.64, Item ID = B09SB9T4ZY, Is Real Item: False
# Rank 171: Score = 79.63, Item ID = B07B8PP7GP, Is Real Item: False
# Rank 172: Score = 79.63, Item ID = B0BX9LKF7M, Is Real Item: False
# Rank 173: Score = 79.63, Item ID = B09XDP44CM, Is Real Item: False
# Rank 174: Score = 79.63, Item ID = B0CCCB2CP2, Is Real Item: False
# Rank 175: Score = 79.62, Item ID = B0976R3WDB, Is Real Item: False
# Rank 176: Score = 79.62, Item ID = B0976R3WDB, Is Real Item: False
# Rank 177: Score = 79.62, Item ID = B0BKNKR4K4, Is Real Item: False
# Rank 178: Score = 79.61, Item ID = B07DPVDD3F, Is Real Item: False
# Rank 179: Score = 79.60, Item ID = B09Z2623DX, Is Real Item: False
# Rank 180: Score = 79.60, Item ID = B0B6VSR11M, Is Real Item: False
# Rank 181: Score = 79.59, Item ID = B09C2P6149, Is Real Item: False
# Rank 182: Score = 79.58, Item ID = B0B4NVC61B, Is Real Item: False
# Rank 183: Score = 79.58, Item ID = B0BY4Z89ML, Is Real Item: False
# Rank 184: Score = 79.58, Item ID = B07TKDJ5Q7, Is Real Item: False
# Rank 185: Score = 79.57, Item ID = B09J4346YF, Is Real Item: False
# Rank 186: Score = 79.57, Item ID = B0B4PJFFM1, Is Real Item: False
# Rank 187: Score = 79.57, Item ID = B08L7TTSY9, Is Real Item: False
# Rank 188: Score = 79.55, Item ID = B071F1KPPX, Is Real Item: False
# Rank 189: Score = 79.55, Item ID = B088LJ43MV, Is Real Item: False
# Rank 190: Score = 79.55, Item ID = B0BMWP2FQT, Is Real Item: False
# Rank 191: Score = 79.55, Item ID = B09N79S3WR, Is Real Item: False
# Rank 192: Score = 79.55, Item ID = B0BHPZG8CZ, Is Real Item: False
# Rank 193: Score = 79.54, Item ID = B08XNCGP54, Is Real Item: False
# Rank 194: Score = 79.54, Item ID = B07CL8D6V5, Is Real Item: False
# Rank 195: Score = 79.53, Item ID = B0C6QQC382, Is Real Item: False
# Rank 196: Score = 79.53, Item ID = B0BYKQQY59, Is Real Item: False
# Rank 197: Score = 79.53, Item ID = B0BQNBNS5K, Is Real Item: False
# Rank 198: Score = 79.53, Item ID = B08RMSJXHL, Is Real Item: False
# Rank 199: Score = 79.53, Item ID = B01LWN4LSD, Is Real Item: False
# Rank 200: Score = 79.51, Item ID = B0BZ1FQ7H7, Is Real Item: False
# Rank 201: Score = 79.51, Item ID = B08P5X5DLX, Is Real Item: False
# Rank 202: Score = 79.51, Item ID = B0BFX4SC26, Is Real Item: False
# Rank 203: Score = 79.51, Item ID = B0BY2QHRLK, Is Real Item: False
# Rank 204: Score = 79.50, Item ID = B099Y42WDK, Is Real Item: False
# Rank 205: Score = 79.49, Item ID = B0B8MG2M6M, Is Real Item: False
# Rank 206: Score = 79.48, Item ID = B0C5S3HZNF, Is Real Item: False
# Rank 207: Score = 79.47, Item ID = B07K1Y51Y9, Is Real Item: False
# Rank 208: Score = 79.47, Item ID = B0BWJNQBGD, Is Real Item: False
# Rank 209: Score = 79.46, Item ID = B0B8F27R5H, Is Real Item: False
# Rank 210: Score = 79.46, Item ID = B08M5Z19YD, Is Real Item: False
# Rank 211: Score = 79.46, Item ID = B093C5LXT8, Is Real Item: False
# Rank 212: Score = 79.46, Item ID = B0BTKC9XGJ, Is Real Item: False
# Rank 213: Score = 79.45, Item ID = B098NC7Q8T, Is Real Item: False
# Rank 214: Score = 79.45, Item ID = B0B829WR28, Is Real Item: False
# Rank 215: Score = 79.45, Item ID = B088183BKS, Is Real Item: False
# Rank 216: Score = 79.45, Item ID = B0C23NDXD8, Is Real Item: False
# Rank 217: Score = 79.44, Item ID = B0BNT8P4LW, Is Real Item: False
# Rank 218: Score = 79.43, Item ID = B0B56LGJRP, Is Real Item: False
# Rank 219: Score = 79.43, Item ID = B0B4W419V4, Is Real Item: False
# Rank 220: Score = 79.43, Item ID = B00MPGSLLW, Is Real Item: False
# Rank 221: Score = 79.42, Item ID = B09NNDJS2R, Is Real Item: False
# Rank 222: Score = 79.41, Item ID = B0969P7WRM, Is Real Item: False
# Rank 223: Score = 79.40, Item ID = B0C7B9YSL2, Is Real Item: False
# Rank 224: Score = 79.40, Item ID = B09H5SQPMX, Is Real Item: False
# Rank 225: Score = 79.40, Item ID = B09XWCTJMW, Is Real Item: False
# Rank 226: Score = 79.40, Item ID = B09XWCTJMW, Is Real Item: False
# Rank 227: Score = 79.39, Item ID = B0044FPNIG, Is Real Item: False
# Rank 228: Score = 79.39, Item ID = B0B7DBF4FD, Is Real Item: False
# Rank 229: Score = 79.39, Item ID = B076814SN1, Is Real Item: False
# Rank 230: Score = 79.38, Item ID = B010Y1U1JO, Is Real Item: False
# Rank 231: Score = 79.38, Item ID = B097T9LSRB, Is Real Item: False
# Rank 232: Score = 79.38, Item ID = B0BXT8HXPD, Is Real Item: False
# Rank 233: Score = 79.38, Item ID = B0B28BDZFZ, Is Real Item: False
# Rank 234: Score = 79.38, Item ID = B0792R5KJF, Is Real Item: False
# Rank 235: Score = 79.38, Item ID = B098B345RH, Is Real Item: False
# Rank 236: Score = 79.37, Item ID = B0B1222NT8, Is Real Item: False
# Rank 237: Score = 79.37, Item ID = B07983QSXT, Is Real Item: False
# Rank 238: Score = 79.36, Item ID = B0172LQDPA, Is Real Item: False
# Rank 239: Score = 79.36, Item ID = B0B4SJXP9W, Is Real Item: False
# Rank 240: Score = 79.35, Item ID = B09LXXXHRQ, Is Real Item: False
# Rank 241: Score = 79.35, Item ID = B0BKR3ZXCS, Is Real Item: False
# Rank 242: Score = 79.35, Item ID = B07JGYWXFQ, Is Real Item: False
# Rank 243: Score = 79.35, Item ID = B0BH2WGL6M, Is Real Item: False
# Rank 244: Score = 79.35, Item ID = B01N23GRYD, Is Real Item: False
# Rank 245: Score = 79.34, Item ID = B09TB4GPRJ, Is Real Item: False
# Rank 246: Score = 79.34, Item ID = B0BX61NXKP, Is Real Item: False
# Rank 247: Score = 79.33, Item ID = B0C86NVY4N, Is Real Item: False
# Rank 248: Score = 79.33, Item ID = B0BKSQ4T37, Is Real Item: False
# Rank 249: Score = 79.32, Item ID = B0BG2VGZG9, Is Real Item: False
# Rank 250: Score = 79.32, Item ID = B09VSX1ZWX, Is Real Item: False
# Rank 251: Score = 79.32, Item ID = B09LC88XRS, Is Real Item: False
# Rank 252: Score = 79.32, Item ID = B0BSN6L2WY, Is Real Item: False
# Rank 253: Score = 79.32, Item ID = B094VQ88X2, Is Real Item: False
# Rank 254: Score = 79.32, Item ID = B0C2K9V7ZR, Is Real Item: False
# Rank 255: Score = 79.31, Item ID = B09N3FGQTH, Is Real Item: False
# Rank 256: Score = 79.31, Item ID = B07K4Q9HS1, Is Real Item: False
# Rank 257: Score = 79.31, Item ID = B000EFFS4Y, Is Real Item: False
# Rank 258: Score = 79.30, Item ID = B07YMY31SX, Is Real Item: False
# Rank 259: Score = 79.30, Item ID = B0B183G11R, Is Real Item: False
# Rank 260: Score = 79.30, Item ID = B00KS6JM0U, Is Real Item: False
# Rank 261: Score = 79.30, Item ID = B0B53GP63V, Is Real Item: False
# Rank 262: Score = 79.30, Item ID = B0BQ6RWJLW, Is Real Item: False
# Rank 263: Score = 79.30, Item ID = B00L7V1REE, Is Real Item: False
# Rank 264: Score = 79.29, Item ID = B08R3DSH37, Is Real Item: False
# Rank 265: Score = 79.29, Item ID = B00PP6QZ80, Is Real Item: False
# Rank 266: Score = 79.29, Item ID = B08LH1SVBJ, Is Real Item: False
# Rank 267: Score = 79.29, Item ID = B0B8VTTBDK, Is Real Item: False
# Rank 268: Score = 79.29, Item ID = B08MQVFTNS, Is Real Item: False
# Rank 269: Score = 79.28, Item ID = B0BHYXW262, Is Real Item: False
# Rank 270: Score = 79.28, Item ID = B0C621D9MS, Is Real Item: False
# Rank 271: Score = 79.28, Item ID = B094JJMWRG, Is Real Item: False
# Rank 272: Score = 79.27, Item ID = B09PVFYJSP, Is Real Item: False
# Rank 273: Score = 79.27, Item ID = B09S54NXN4, Is Real Item: False
# Rank 274: Score = 79.27, Item ID = B0B4ZN1PLW, Is Real Item: False
# Rank 275: Score = 79.26, Item ID = B08Y93M3N3, Is Real Item: False
# Rank 276: Score = 79.26, Item ID = B07S9RJTF9, Is Real Item: False
# Rank 277: Score = 79.26, Item ID = B000NZB60U, Is Real Item: False
# Rank 278: Score = 79.26, Item ID = B07H717RSV, Is Real Item: False
# Rank 279: Score = 79.25, Item ID = B0949MX825, Is Real Item: False
# Rank 280: Score = 79.25, Item ID = B07YSX2821, Is Real Item: False
# Rank 281: Score = 79.25, Item ID = B07WS6HRY1, Is Real Item: False
# Rank 282: Score = 79.24, Item ID = B07W46BX31, Is Real Item: False
# Rank 283: Score = 79.24, Item ID = B07W46BX31, Is Real Item: False
# Rank 284: Score = 79.24, Item ID = B093GGT7Y7, Is Real Item: False
# Rank 285: Score = 79.24, Item ID = B091W7DQGB, Is Real Item: False
# Rank 286: Score = 79.23, Item ID = B0B8Z4SHC3, Is Real Item: False
# Rank 287: Score = 79.23, Item ID = B0B8CD25WH, Is Real Item: False
# Rank 288: Score = 79.23, Item ID = B01MRUKFQ8, Is Real Item: False
# Rank 289: Score = 79.22, Item ID = B0BY8FK656, Is Real Item: False
# Rank 290: Score = 79.22, Item ID = B09R3J7HKT, Is Real Item: False
# Rank 291: Score = 79.22, Item ID = B0C711Z9RF, Is Real Item: False
# Rank 292: Score = 79.22, Item ID = B07589FJZL, Is Real Item: False
# Rank 293: Score = 79.22, Item ID = B0BVG7XQCF, Is Real Item: False
# Rank 294: Score = 79.21, Item ID = B0C23DV3SD, Is Real Item: False
# Rank 295: Score = 79.21, Item ID = B0BVVB4SX4, Is Real Item: False
# Rank 296: Score = 79.21, Item ID = B06VVBSFTF, Is Real Item: False
# Rank 297: Score = 79.21, Item ID = B0C4GY5QJP, Is Real Item: False
# Rank 298: Score = 79.20, Item ID = B08DV772BL, Is Real Item: False
# Rank 299: Score = 79.20, Item ID = B07T7KX7TY, Is Real Item: False
# Rank 300: Score = 79.20, Item ID = B09YRQ3YKD, Is Real Item: False
# Rank 301: Score = 79.20, Item ID = B09C5CKWMV, Is Real Item: False
# Rank 302: Score = 79.19, Item ID = B0BFL82QWC, Is Real Item: False
# Rank 303: Score = 79.19, Item ID = B07KWF1RJJ, Is Real Item: False
# Rank 304: Score = 79.19, Item ID = B0CFZPQ17R, Is Real Item: False
# Rank 305: Score = 79.19, Item ID = B0CFZPQ17R, Is Real Item: False
# Rank 306: Score = 79.18, Item ID = B0BQJ19HLQ, Is Real Item: False
# Rank 307: Score = 79.18, Item ID = B0C6F5W1RV, Is Real Item: False
# Rank 308: Score = 79.18, Item ID = B0C58YDQ5H, Is Real Item: False
# Rank 309: Score = 79.18, Item ID = B093TQTHV7, Is Real Item: False
# Rank 310: Score = 79.18, Item ID = B0B9MF3334, Is Real Item: False
# Rank 311: Score = 79.17, Item ID = B08L14GDWJ, Is Real Item: False
# Rank 312: Score = 79.17, Item ID = B015MMA1Q8, Is Real Item: False
# Rank 313: Score = 79.17, Item ID = B0C4ML8FB3, Is Real Item: False
# Rank 314: Score = 79.17, Item ID = B00XVQ7KEO, Is Real Item: False
# Rank 315: Score = 79.17, Item ID = B00R6DGSAK, Is Real Item: False
# Rank 316: Score = 79.16, Item ID = B09Z47C9MD, Is Real Item: False
# Rank 317: Score = 79.16, Item ID = B09N5QHX7M, Is Real Item: False
# Rank 318: Score = 79.16, Item ID = B0B7KJ33HD, Is Real Item: False
# Rank 319: Score = 79.16, Item ID = B0B8S39Z7V, Is Real Item: False
# Rank 320: Score = 79.16, Item ID = B093WMF7NW, Is Real Item: False
# Rank 321: Score = 79.16, Item ID = B0BQZSF1P4, Is Real Item: False
# Rank 322: Score = 79.15, Item ID = B0BN833CNL, Is Real Item: False
# Rank 323: Score = 79.15, Item ID = B0BD4L6DLK, Is Real Item: False
# Rank 324: Score = 79.15, Item ID = B08NCHPM7M, Is Real Item: False
# Rank 325: Score = 79.14, Item ID = B09R1TYNP9, Is Real Item: False
# Rank 326: Score = 79.14, Item ID = B0C372DYSP, Is Real Item: False
# Rank 327: Score = 79.14, Item ID = B08KH81W9Q, Is Real Item: False
# Rank 328: Score = 79.13, Item ID = B0932RRQ4M, Is Real Item: False
# Rank 329: Score = 79.13, Item ID = B01D3QEK4E, Is Real Item: False
# Rank 330: Score = 79.13, Item ID = B07KVCFT2K, Is Real Item: False
# Rank 331: Score = 79.12, Item ID = B082STNSD9, Is Real Item: False
# Rank 332: Score = 79.12, Item ID = B0C1FPFTG2, Is Real Item: False
# Rank 333: Score = 79.12, Item ID = B09FF615JH, Is Real Item: False
# Rank 334: Score = 79.12, Item ID = B09P2T3X5F, Is Real Item: False
# Rank 335: Score = 79.12, Item ID = B09P2T3X5F, Is Real Item: False
# Rank 336: Score = 79.11, Item ID = B0BNNRWZJ2, Is Real Item: False
# Rank 337: Score = 79.11, Item ID = B0BL1FMQ7W, Is Real Item: False
# Rank 338: Score = 79.10, Item ID = B0875N9XF8, Is Real Item: False
# Rank 339: Score = 79.10, Item ID = B092R36QFD, Is Real Item: False
# Rank 340: Score = 79.10, Item ID = B0734QN8KR, Is Real Item: False
# Rank 341: Score = 79.10, Item ID = B075CZCTXM, Is Real Item: False
# Rank 342: Score = 79.10, Item ID = B0BY7VZ12H, Is Real Item: False
# Rank 343: Score = 79.10, Item ID = B07FB9ZGWJ, Is Real Item: False
# Rank 344: Score = 79.10, Item ID = B08RP6P1QX, Is Real Item: False
# Rank 345: Score = 79.09, Item ID = B09TDJB1Z1, Is Real Item: False
# Rank 346: Score = 79.09, Item ID = B088X4XBB9, Is Real Item: False
# Rank 347: Score = 79.09, Item ID = B0CB91P3XY, Is Real Item: False
# Rank 348: Score = 79.08, Item ID = B093HCK586, Is Real Item: False
# Rank 349: Score = 79.08, Item ID = B08F37P7H3, Is Real Item: False
# Rank 350: Score = 79.08, Item ID = B09N1VNWF3, Is Real Item: False
# Rank 351: Score = 79.07, Item ID = B08RBL1X8S, Is Real Item: False
# Rank 352: Score = 79.07, Item ID = B07FDW6ZQ8, Is Real Item: False
# Rank 353: Score = 79.07, Item ID = B07FDW6ZQ8, Is Real Item: False
# Rank 354: Score = 79.07, Item ID = B09MHXVVC7, Is Real Item: False
# Rank 355: Score = 79.06, Item ID = B00EYWHOBS, Is Real Item: False
# Rank 356: Score = 79.06, Item ID = B09SYZ7PZ2, Is Real Item: False
# Rank 357: Score = 79.06, Item ID = B0CGV93978, Is Real Item: False
# Rank 358: Score = 79.06, Item ID = B06XRZW1LD, Is Real Item: False
# Rank 359: Score = 79.06, Item ID = B09P4T34SQ, Is Real Item: False
# Rank 360: Score = 79.05, Item ID = B07J46LD5F, Is Real Item: False
# Rank 361: Score = 79.05, Item ID = B008N3JT8A, Is Real Item: False
# Rank 362: Score = 79.05, Item ID = B099J97DMD, Is Real Item: False
# Rank 363: Score = 79.05, Item ID = B07PG6RXLN, Is Real Item: False
# Rank 364: Score = 79.04, Item ID = B0B6BHTJ12, Is Real Item: False
# Rank 365: Score = 79.04, Item ID = B092PVCQQP, Is Real Item: False
# Rank 366: Score = 79.04, Item ID = B0B74NVY9P, Is Real Item: False
# Rank 367: Score = 79.03, Item ID = B0C6356B31, Is Real Item: False
# Rank 368: Score = 79.03, Item ID = B0BJ5X2KG2, Is Real Item: False
# Rank 369: Score = 79.03, Item ID = B0C67LY8QM, Is Real Item: False
# Rank 370: Score = 79.03, Item ID = B0BFGV2CDB, Is Real Item: False
# Rank 371: Score = 79.03, Item ID = B01B3JZWDQ, Is Real Item: False
# Rank 372: Score = 79.03, Item ID = B07Q4RCLL1, Is Real Item: False
# Rank 373: Score = 79.03, Item ID = B09K7K9BCH, Is Real Item: False
# Rank 374: Score = 79.03, Item ID = B08GC3ZSDW, Is Real Item: False
# Rank 375: Score = 79.02, Item ID = B00IY3YLCI, Is Real Item: False
# Rank 376: Score = 79.02, Item ID = B0C68PRTZ4, Is Real Item: False
# Rank 377: Score = 79.01, Item ID = B0BKSXM8VN, Is Real Item: False
# Rank 378: Score = 79.01, Item ID = B08YDL85W8, Is Real Item: False
# Rank 379: Score = 79.01, Item ID = B08NRW82B7, Is Real Item: False
# Rank 380: Score = 79.00, Item ID = B09BYKJ2HC, Is Real Item: False
# Rank 381: Score = 79.00, Item ID = B09GM56893, Is Real Item: False
# Rank 382: Score = 79.00, Item ID = B07STLQ4P9, Is Real Item: False
# Rank 383: Score = 79.00, Item ID = B0B8T8L8TY, Is Real Item: False
# Rank 384: Score = 79.00, Item ID = B0B7DKYXWR, Is Real Item: False
# Rank 385: Score = 79.00, Item ID = B09B9MBSJZ, Is Real Item: False
# Rank 386: Score = 79.00, Item ID = B0B387GVVC, Is Real Item: False
# Rank 387: Score = 79.00, Item ID = B0B387GVVC, Is Real Item: False
# Rank 388: Score = 79.00, Item ID = B08TCH7NLW, Is Real Item: False
# Rank 389: Score = 79.00, Item ID = B09PHP2452, Is Real Item: False
# Rank 390: Score = 79.00, Item ID = B09PHP2452, Is Real Item: False
# Rank 391: Score = 78.99, Item ID = B07R4J9446, Is Real Item: False
# Rank 392: Score = 78.99, Item ID = B07NXPG9MZ, Is Real Item: False
# Rank 393: Score = 78.99, Item ID = B0BNVH8973, Is Real Item: False
# Rank 394: Score = 78.99, Item ID = B07B8YJLGL, Is Real Item: False
# Rank 395: Score = 78.99, Item ID = B01ARY90NQ, Is Real Item: False
# Rank 396: Score = 78.99, Item ID = B0BZ7KXXW8, Is Real Item: False
# Rank 397: Score = 78.98, Item ID = B09ZDFJHDN, Is Real Item: False
# Rank 398: Score = 78.98, Item ID = B07GRC7BYY, Is Real Item: False
# Rank 399: Score = 78.98, Item ID = B0991V426W, Is Real Item: False
# Rank 400: Score = 78.97, Item ID = B01N67G7ZY, Is Real Item: False
# Rank 401: Score = 78.97, Item ID = B0BNVFFZN6, Is Real Item: False
# Rank 402: Score = 78.97, Item ID = B09HS97PPM, Is Real Item: False
# Rank 403: Score = 78.97, Item ID = B00Y1HRMFO, Is Real Item: False
# Rank 404: Score = 78.97, Item ID = B09Y5TB89Q, Is Real Item: False
# Rank 405: Score = 78.97, Item ID = B09Y5TB89Q, Is Real Item: False
# Rank 406: Score = 78.97, Item ID = B0B8QBTS8D, Is Real Item: False
# Rank 407: Score = 78.97, Item ID = B07RQW6SD5, Is Real Item: False
# Rank 408: Score = 78.96, Item ID = B0B4XBXN17, Is Real Item: False
# Rank 409: Score = 78.96, Item ID = B0B979H59S, Is Real Item: False
# Rank 410: Score = 78.96, Item ID = B07RV1PGPG, Is Real Item: False
# Rank 411: Score = 78.95, Item ID = B09NXNLGNB, Is Real Item: False
# Rank 412: Score = 78.95, Item ID = B09V12ZSBV, Is Real Item: False
# Rank 413: Score = 78.95, Item ID = B07RVFG9N5, Is Real Item: False
# Rank 414: Score = 78.94, Item ID = B09PYBGVSQ, Is Real Item: False
# Rank 415: Score = 78.94, Item ID = B09CHHLJ1H, Is Real Item: False
# Rank 416: Score = 78.94, Item ID = B0C5T94ZYF, Is Real Item: False
# Rank 417: Score = 78.94, Item ID = B0BCX21N52, Is Real Item: False
# Rank 418: Score = 78.93, Item ID = B07F5QBRSF, Is Real Item: False
# Rank 419: Score = 78.93, Item ID = B0BLCVXGP2, Is Real Item: False
# Rank 420: Score = 78.93, Item ID = B07PND3719, Is Real Item: False
# Rank 421: Score = 78.93, Item ID = B0028QGTVS, Is Real Item: False
# Rank 422: Score = 78.92, Item ID = B0B7XTX768, Is Real Item: False
# Rank 423: Score = 78.92, Item ID = B085WXKGHN, Is Real Item: False
# Rank 424: Score = 78.92, Item ID = B07H899LT7, Is Real Item: False
# Rank 425: Score = 78.92, Item ID = B0BS17YCM2, Is Real Item: False
# Rank 426: Score = 78.92, Item ID = B08VNPFX2S, Is Real Item: False
# Rank 427: Score = 78.92, Item ID = B0BT1KWZKH, Is Real Item: False
# Rank 428: Score = 78.91, Item ID = B075Q2SSKX, Is Real Item: False
# Rank 429: Score = 78.91, Item ID = B09Z1RGVPN, Is Real Item: False
# Rank 430: Score = 78.91, Item ID = B09MLM7BQJ, Is Real Item: False
# Rank 431: Score = 78.91, Item ID = B00CC00RS6, Is Real Item: False
# Rank 432: Score = 78.91, Item ID = B08YNP771T, Is Real Item: False
# Rank 433: Score = 78.91, Item ID = B0BM8QK64K, Is Real Item: False
# Rank 434: Score = 78.90, Item ID = B0BWCRJ6P1, Is Real Item: False
# Rank 435: Score = 78.90, Item ID = B09DF9XMPK, Is Real Item: False
# Rank 436: Score = 78.90, Item ID = B0B8RN3BGY, Is Real Item: False
# Rank 437: Score = 78.90, Item ID = B09QLSKYY3, Is Real Item: False
# Rank 438: Score = 78.90, Item ID = B093S2RT5L, Is Real Item: False
# Rank 439: Score = 78.89, Item ID = B0BZ1NX34Q, Is Real Item: False
# Rank 440: Score = 78.89, Item ID = B09WDKSHTN, Is Real Item: False
# Rank 441: Score = 78.89, Item ID = B0BBLZQ3MT, Is Real Item: False
# Rank 442: Score = 78.89, Item ID = B07S1ML3RM, Is Real Item: False
# Rank 443: Score = 78.89, Item ID = B01M3VQHAR, Is Real Item: False
# Rank 444: Score = 78.89, Item ID = B0C7RCZD9Q, Is Real Item: False
# Rank 445: Score = 78.89, Item ID = B089SJST2J, Is Real Item: False
# Rank 446: Score = 78.89, Item ID = B08RDK83LB, Is Real Item: False
# Rank 447: Score = 78.88, Item ID = B0B5CS7NZG, Is Real Item: False
# Rank 448: Score = 78.88, Item ID = B087KVTTHP, Is Real Item: False
# Rank 449: Score = 78.88, Item ID = B09XMBLWSY, Is Real Item: False
# Rank 450: Score = 78.88, Item ID = B0BFQHVJHD, Is Real Item: False
# Rank 451: Score = 78.88, Item ID = B08BXTLS6F, Is Real Item: False
# Rank 452: Score = 78.88, Item ID = B07HSS8FFF, Is Real Item: False
# Rank 453: Score = 78.87, Item ID = B09NLR5GNY, Is Real Item: False
# Rank 454: Score = 78.87, Item ID = B01ICC6QF0, Is Real Item: False
# Rank 455: Score = 78.87, Item ID = B08M41FX48, Is Real Item: False
# Rank 456: Score = 78.87, Item ID = B08M41FX48, Is Real Item: False
# Rank 457: Score = 78.87, Item ID = B09TRD4MNG, Is Real Item: False
# Rank 458: Score = 78.87, Item ID = B08Z5RY9VD, Is Real Item: False
# Rank 459: Score = 78.87, Item ID = B0C69K84M4, Is Real Item: False
# Rank 460: Score = 78.87, Item ID = B0BL3K74FS, Is Real Item: False
# Rank 461: Score = 78.86, Item ID = B093GTJQ6D, Is Real Item: False
# Rank 462: Score = 78.85, Item ID = B0943KLW9P, Is Real Item: False
# Rank 463: Score = 78.85, Item ID = B08ZSPHHNW, Is Real Item: False
# Rank 464: Score = 78.85, Item ID = B08H4C234W, Is Real Item: False
# Rank 465: Score = 78.85, Item ID = B09D3FX6TX, Is Real Item: False
# Rank 466: Score = 78.85, Item ID = B0B7KVMRZV, Is Real Item: False
# Rank 467: Score = 78.85, Item ID = B0922SKH8S, Is Real Item: False
# Rank 468: Score = 78.85, Item ID = B08JZ9CM5Y, Is Real Item: False
# Rank 469: Score = 78.85, Item ID = B09KRL8FML, Is Real Item: False
# Rank 470: Score = 78.85, Item ID = B09FCVLKPQ, Is Real Item: False
# Rank 471: Score = 78.84, Item ID = B07RB7GLJH, Is Real Item: False
# Rank 472: Score = 78.84, Item ID = B07SX75TDS, Is Real Item: False
# Rank 473: Score = 78.83, Item ID = B08RZ24ZC4, Is Real Item: False
# Rank 474: Score = 78.83, Item ID = B0B2P7CMT7, Is Real Item: False
# Rank 475: Score = 78.83, Item ID = B07X1Z8JR6, Is Real Item: False
# Rank 476: Score = 78.83, Item ID = B083TP31T6, Is Real Item: False
# Rank 477: Score = 78.83, Item ID = B09HZVX4GC, Is Real Item: False
# Rank 478: Score = 78.82, Item ID = B098NJN9K1, Is Real Item: False
# Rank 479: Score = 78.82, Item ID = B08BCLMSS3, Is Real Item: False
# Rank 480: Score = 78.82, Item ID = B0BRQ5PL3Z, Is Real Item: False
# Rank 481: Score = 78.82, Item ID = B07HX9LD3H, Is Real Item: False
# Rank 482: Score = 78.82, Item ID = B06XTP3HDG, Is Real Item: False
# Rank 483: Score = 78.82, Item ID = B084GDTCT6, Is Real Item: False
# Rank 484: Score = 78.82, Item ID = B08LTZQKYJ, Is Real Item: False
# Rank 485: Score = 78.81, Item ID = B09HPYMLTS, Is Real Item: False
# Rank 486: Score = 78.81, Item ID = B0BB192PXK, Is Real Item: False
# Rank 487: Score = 78.81, Item ID = B0BKLCFRKN, Is Real Item: False
# Rank 488: Score = 78.81, Item ID = B00BYH6C1E, Is Real Item: False
# Rank 489: Score = 78.81, Item ID = B00BYH6C1E, Is Real Item: False
# Rank 490: Score = 78.81, Item ID = B0831KS3YW, Is Real Item: False
# Rank 491: Score = 78.81, Item ID = B0C7BLM5WX, Is Real Item: False
# Rank 492: Score = 78.81, Item ID = B09NFRPWMY, Is Real Item: False
# Rank 493: Score = 78.80, Item ID = B09ZVN18ZD, Is Real Item: False
# Rank 494: Score = 78.80, Item ID = B0967QT47K, Is Real Item: False
# Rank 495: Score = 78.80, Item ID = B09QKT726Q, Is Real Item: False
# Rank 496: Score = 78.80, Item ID = B0BN9WXQKB, Is Real Item: False
# Rank 497: Score = 78.79, Item ID = B0BWDY68XZ, Is Real Item: False
# Rank 498: Score = 78.79, Item ID = B0CBDFL2KJ, Is Real Item: False
# Rank 499: Score = 78.79, Item ID = B0BHY59CS7, Is Real Item: False
# Rank 500: Score = 78.79, Item ID = B08ZK3KJ7K, Is Real Item: False
# Rank 501: Score = 78.79, Item ID = B0BFQRC815, Is Real Item: False
# Rank 502: Score = 78.77, Item ID = B0B1WFHP5Q, Is Real Item: False
# Rank 503: Score = 78.77, Item ID = B00H6QR8D8, Is Real Item: False
# Rank 504: Score = 78.77, Item ID = B0B3MJMPMM, Is Real Item: False
# Rank 505: Score = 78.77, Item ID = B09LRFW4W5, Is Real Item: False
# Rank 506: Score = 78.77, Item ID = B0C59HR89D, Is Real Item: False
# Rank 507: Score = 78.76, Item ID = B06Y5FR86L, Is Real Item: False
# Rank 508: Score = 78.76, Item ID = B0BYSDZXRR, Is Real Item: False
# Rank 509: Score = 78.76, Item ID = B0BYSDZXRR, Is Real Item: False
# Rank 510: Score = 78.76, Item ID = B0C7C43LVB, Is Real Item: False
# Rank 511: Score = 78.76, Item ID = B09474MX51, Is Real Item: False
# Rank 512: Score = 78.76, Item ID = B09MD9YBQ5, Is Real Item: False
# Rank 513: Score = 78.75, Item ID = B09P5DZ5LM, Is Real Item: False
# Rank 514: Score = 78.75, Item ID = B0CDRS3H9Y, Is Real Item: False
# Rank 515: Score = 78.75, Item ID = B0B9M871G2, Is Real Item: False
# Rank 516: Score = 78.75, Item ID = B07S2B8C46, Is Real Item: False
# Rank 517: Score = 78.75, Item ID = B0BWY148RL, Is Real Item: False
# Rank 518: Score = 78.75, Item ID = B0BT3CQ2W9, Is Real Item: False
# Rank 519: Score = 78.74, Item ID = B0B3XS96SB, Is Real Item: False
# Rank 520: Score = 78.74, Item ID = B08N1GRNQD, Is Real Item: False
# Rank 521: Score = 78.74, Item ID = B08MZYVDY9, Is Real Item: False
# Rank 522: Score = 78.74, Item ID = B083YZ7WCR, Is Real Item: False
# Rank 523: Score = 78.74, Item ID = B09TGXTQK7, Is Real Item: False
# Rank 524: Score = 78.74, Item ID = B07YTXN2MZ, Is Real Item: False
# Rank 525: Score = 78.74, Item ID = B0BX6H6PKR, Is Real Item: False
# Rank 526: Score = 78.73, Item ID = B0BC8M3Q8V, Is Real Item: False
# Rank 527: Score = 78.73, Item ID = B09QZGR93X, Is Real Item: False
# Rank 528: Score = 78.73, Item ID = B09W2QFXHD, Is Real Item: False
# Rank 529: Score = 78.73, Item ID = B0BHDM6K55, Is Real Item: False
# Rank 530: Score = 78.73, Item ID = B0BVZJHWJ3, Is Real Item: False
# Rank 531: Score = 78.73, Item ID = B0BZ3DV3ZP, Is Real Item: False
# Rank 532: Score = 78.73, Item ID = B00CKDGP0O, Is Real Item: False
# Rank 533: Score = 78.73, Item ID = B07MBQV4JK, Is Real Item: False
# Rank 534: Score = 78.73, Item ID = B0BJCYZ2N3, Is Real Item: False
# Rank 535: Score = 78.72, Item ID = B0B3D96MN6, Is Real Item: False
# Rank 536: Score = 78.72, Item ID = B0C4FJWFDH, Is Real Item: False
# Rank 537: Score = 78.72, Item ID = B0C1T3DRTR, Is Real Item: False
# Rank 538: Score = 78.72, Item ID = B08CV379G9, Is Real Item: False
# Rank 539: Score = 78.72, Item ID = B088FJBGJ4, Is Real Item: False
# Rank 540: Score = 78.71, Item ID = B0B5Y43QM3, Is Real Item: False
# Rank 541: Score = 78.71, Item ID = B0725RRRS5, Is Real Item: False
# Rank 542: Score = 78.71, Item ID = B08TWJ6KMN, Is Real Item: False
# Rank 543: Score = 78.71, Item ID = B07VKBSB4P, Is Real Item: False
# Rank 544: Score = 78.71, Item ID = B098PYB8XG, Is Real Item: False
# Rank 545: Score = 78.71, Item ID = B0CG3BDWYT, Is Real Item: False
# Rank 546: Score = 78.71, Item ID = B0C27SCXG6, Is Real Item: False
# Rank 547: Score = 78.71, Item ID = B0BCGCTFVN, Is Real Item: False
# Rank 548: Score = 78.71, Item ID = B09TTKH8K6, Is Real Item: False
# Rank 549: Score = 78.70, Item ID = B0B8G8S976, Is Real Item: False
# Rank 550: Score = 78.70, Item ID = B07SX5M9R6, Is Real Item: False
# Rank 551: Score = 78.70, Item ID = B07LB8Z1ZN, Is Real Item: False
# Rank 552: Score = 78.70, Item ID = B0BP9CHQK9, Is Real Item: False
# Rank 553: Score = 78.70, Item ID = B0CBDH57WG, Is Real Item: False
# Rank 554: Score = 78.70, Item ID = B075ZP5TJX, Is Real Item: False
# Rank 555: Score = 78.69, Item ID = B08HM9P1VD, Is Real Item: False
# Rank 556: Score = 78.69, Item ID = B09V2T9RLM, Is Real Item: False
# Rank 557: Score = 78.69, Item ID = B087F3HCX2, Is Real Item: False
# Rank 558: Score = 78.69, Item ID = B005HPVXYK, Is Real Item: False
# Rank 559: Score = 78.69, Item ID = B0CG9XLNXQ, Is Real Item: False
# Rank 560: Score = 78.68, Item ID = B07WDNK25J, Is Real Item: False
# Rank 561: Score = 78.68, Item ID = B00004RBDW, Is Real Item: False
# Rank 562: Score = 78.68, Item ID = B0BQR5F2MP, Is Real Item: False
# Rank 563: Score = 78.68, Item ID = B0BQR5F2MP, Is Real Item: False
# Rank 564: Score = 78.68, Item ID = B0BLH57T65, Is Real Item: False
# Rank 565: Score = 78.68, Item ID = B0B2RG2YHL, Is Real Item: False
# Rank 566: Score = 78.67, Item ID = B0BYN6LQ81, Is Real Item: False
# Rank 567: Score = 78.67, Item ID = B0BT27PDVV, Is Real Item: False
# Rank 568: Score = 78.67, Item ID = B0BFGCF41N, Is Real Item: False
# Rank 569: Score = 78.67, Item ID = B09M3JLSVF, Is Real Item: False
# Rank 570: Score = 78.67, Item ID = B0BV1L1LTG, Is Real Item: False
# Rank 571: Score = 78.67, Item ID = B0C4D3TKRN, Is Real Item: False
# Rank 572: Score = 78.66, Item ID = B0B8QWH7VT, Is Real Item: False
# Rank 573: Score = 78.66, Item ID = B09NLMQ24D, Is Real Item: False
# Rank 574: Score = 78.66, Item ID = B075F214K1, Is Real Item: False
# Rank 575: Score = 78.66, Item ID = B08X1MSNNX, Is Real Item: False
# Rank 576: Score = 78.65, Item ID = B09LXN9TMM, Is Real Item: False
# Rank 577: Score = 78.65, Item ID = B09LXN9TMM, Is Real Item: False
# Rank 578: Score = 78.65, Item ID = B0BXKSHXVY, Is Real Item: False
# Rank 579: Score = 78.65, Item ID = B09R1JP1HG, Is Real Item: False
# Rank 580: Score = 78.65, Item ID = B09V71SQRJ, Is Real Item: False
# Rank 581: Score = 78.65, Item ID = B0CGWLSZGT, Is Real Item: False
# Rank 582: Score = 78.65, Item ID = B0C2J44PLM, Is Real Item: False
# Rank 583: Score = 78.65, Item ID = B0C2J44PLM, Is Real Item: False
# Rank 584: Score = 78.65, Item ID = B07KZSYHQG, Is Real Item: False
# Rank 585: Score = 78.65, Item ID = B0BCK8NP5S, Is Real Item: False
# Rank 586: Score = 78.65, Item ID = B0CCNRF72S, Is Real Item: False
# Rank 587: Score = 78.64, Item ID = B09HGM44DV, Is Real Item: False
# Rank 588: Score = 78.64, Item ID = B0B5ZRM249, Is Real Item: False
# Rank 589: Score = 78.64, Item ID = B0B14XW4WN, Is Real Item: False
# Rank 590: Score = 78.64, Item ID = B09SJ1WM6P, Is Real Item: False
# Rank 591: Score = 78.64, Item ID = B0C3VKMDTN, Is Real Item: False
# Rank 592: Score = 78.64, Item ID = B07MP1Q3W8, Is Real Item: False
# Rank 593: Score = 78.64, Item ID = B0BYHGD4HC, Is Real Item: False
# Rank 594: Score = 78.63, Item ID = B0B4B19ZRG, Is Real Item: False
# Rank 595: Score = 78.63, Item ID = B0BTNBPTTB, Is Real Item: False
# Rank 596: Score = 78.63, Item ID = B09962CTGX, Is Real Item: False
# Rank 597: Score = 78.63, Item ID = B0BC1BHSZF, Is Real Item: False
# Rank 598: Score = 78.63, Item ID = B07GY1YR64, Is Real Item: False
# Rank 599: Score = 78.63, Item ID = B073XRSCBH, Is Real Item: False
# Rank 600: Score = 78.62, Item ID = B09MB445SJ, Is Real Item: False
# Rank 601: Score = 78.62, Item ID = B0BSB5CCCC, Is Real Item: False
# Rank 602: Score = 78.62, Item ID = B0919H77FL, Is Real Item: False
# Rank 603: Score = 78.62, Item ID = B08HK4FY28, Is Real Item: False
# Rank 604: Score = 78.62, Item ID = B0BY8T4KM2, Is Real Item: False
# Rank 605: Score = 78.62, Item ID = B08H4RSXT1, Is Real Item: False
# Rank 606: Score = 78.62, Item ID = B07ZYLHVSM, Is Real Item: False
# Rank 607: Score = 78.61, Item ID = B094C2NKBV, Is Real Item: False
# Rank 608: Score = 78.61, Item ID = B098N7QMGC, Is Real Item: False
# Rank 609: Score = 78.61, Item ID = B07FKTP7L9, Is Real Item: False
# Rank 610: Score = 78.61, Item ID = B076J5HCWP, Is Real Item: False
# Rank 611: Score = 78.61, Item ID = B07NV4QVS4, Is Real Item: False
# Rank 612: Score = 78.61, Item ID = B09MLF93FW, Is Real Item: False
# Rank 613: Score = 78.60, Item ID = B0C3WV37SZ, Is Real Item: False
# Rank 614: Score = 78.60, Item ID = B093VLG4BQ, Is Real Item: False
# Rank 615: Score = 78.60, Item ID = B07Y3YY9YX, Is Real Item: False
# Rank 616: Score = 78.60, Item ID = B07MVW593Y, Is Real Item: False
# Rank 617: Score = 78.59, Item ID = B0BZNTVYF8, Is Real Item: False
# Rank 618: Score = 78.59, Item ID = B07H9FVG3Z, Is Real Item: False
# Rank 619: Score = 78.59, Item ID = B00BJMF832, Is Real Item: False
# Rank 620: Score = 78.59, Item ID = B0BNTNKY4Y, Is Real Item: False
# Rank 621: Score = 78.59, Item ID = B0BBGH6ZH1, Is Real Item: False
# Rank 622: Score = 78.59, Item ID = B093LSY57L, Is Real Item: False
# Rank 623: Score = 78.59, Item ID = B09D76KH3C, Is Real Item: False
# Rank 624: Score = 78.59, Item ID = B0BBLX4VKT, Is Real Item: False
# Rank 625: Score = 78.59, Item ID = B08HPGZTJ8, Is Real Item: False
# Rank 626: Score = 78.59, Item ID = B0C5L29Q62, Is Real Item: False
# Rank 627: Score = 78.59, Item ID = B00VQLBSR6, Is Real Item: False
# Rank 628: Score = 78.59, Item ID = B08CXDZMNK, Is Real Item: False
# Rank 629: Score = 78.59, Item ID = B0BTP5V6KD, Is Real Item: False
# Rank 630: Score = 78.58, Item ID = B0B6QTLFNY, Is Real Item: False
# Rank 631: Score = 78.58, Item ID = B0C23Y82BV, Is Real Item: False
# Rank 632: Score = 78.58, Item ID = B088WH6HBM, Is Real Item: False
# Rank 633: Score = 78.58, Item ID = B097M4LLJN, Is Real Item: False
# Rank 634: Score = 78.58, Item ID = B0B5X417FH, Is Real Item: False
# Rank 635: Score = 78.58, Item ID = B0C4V5PGXN, Is Real Item: False
# Rank 636: Score = 78.58, Item ID = B0BLYFRGQ9, Is Real Item: False
# Rank 637: Score = 78.58, Item ID = B0B7BM6PGQ, Is Real Item: False
# Rank 638: Score = 78.58, Item ID = B0BGLPGZPV, Is Real Item: False
# Rank 639: Score = 78.58, Item ID = B0BMQ4PGVB, Is Real Item: False
# Rank 640: Score = 78.57, Item ID = B07XM63SBR, Is Real Item: False
# Rank 641: Score = 78.57, Item ID = B0BSG8G8MD, Is Real Item: False
# Rank 642: Score = 78.57, Item ID = B0BTHLHGPV, Is Real Item: False
# Rank 643: Score = 78.57, Item ID = B0BQF9TJFB, Is Real Item: False
# Rank 644: Score = 78.57, Item ID = B0BQ797J3W, Is Real Item: False
# Rank 645: Score = 78.57, Item ID = B0B6KJRXL4, Is Real Item: False
# Rank 646: Score = 78.57, Item ID = B098JP1TVR, Is Real Item: False
# Rank 647: Score = 78.56, Item ID = B0C65X2XPQ, Is Real Item: False
# Rank 648: Score = 78.56, Item ID = B09SHFL8LD, Is Real Item: False
# Rank 649: Score = 78.56, Item ID = B0747W6ZF9, Is Real Item: False
# Rank 650: Score = 78.55, Item ID = B0C5X79RKL, Is Real Item: False
# Rank 651: Score = 78.55, Item ID = B08BXSTFWK, Is Real Item: False
# Rank 652: Score = 78.55, Item ID = B093YJRZ8H, Is Real Item: False
# Rank 653: Score = 78.55, Item ID = B07L5RF5CW, Is Real Item: False
# Rank 654: Score = 78.55, Item ID = B0951TFZNP, Is Real Item: False
# Rank 655: Score = 78.55, Item ID = B09QF1XZPF, Is Real Item: False
# Rank 656: Score = 78.55, Item ID = B082MCSRC7, Is Real Item: False
# Rank 657: Score = 78.55, Item ID = B09YNWXQJ5, Is Real Item: False
# Rank 658: Score = 78.54, Item ID = B07D9BY5M2, Is Real Item: False
# Rank 659: Score = 78.54, Item ID = B07SYV9PDK, Is Real Item: False
# Rank 660: Score = 78.54, Item ID = B08JMG94X4, Is Real Item: False
# Rank 661: Score = 78.54, Item ID = B0B2K8XQFZ, Is Real Item: False
# Rank 662: Score = 78.54, Item ID = B002NGUVGM, Is Real Item: False
# Rank 663: Score = 78.54, Item ID = B0C96TTQYG, Is Real Item: False
# Rank 664: Score = 78.54, Item ID = B07Y3Z9SRQ, Is Real Item: False
# Rank 665: Score = 78.53, Item ID = B0BVR4Q3XM, Is Real Item: False
# Rank 666: Score = 78.53, Item ID = B09QS1DBR9, Is Real Item: False
# Rank 667: Score = 78.53, Item ID = B0BLZ84M4Y, Is Real Item: False
# Rank 668: Score = 78.53, Item ID = B09YVL4JB1, Is Real Item: False
# Rank 669: Score = 78.52, Item ID = B0BXHBCCS6, Is Real Item: False
# Rank 670: Score = 78.52, Item ID = B0CBBM43VF, Is Real Item: False
# Rank 671: Score = 78.52, Item ID = B0B72MKSCN, Is Real Item: False
# Rank 672: Score = 78.52, Item ID = B07PDHB7RL, Is Real Item: False
# Rank 673: Score = 78.52, Item ID = B09D6ZDDRJ, Is Real Item: False
# Rank 674: Score = 78.52, Item ID = B0BLYWG3XB, Is Real Item: False
# Rank 675: Score = 78.52, Item ID = B07ZBM2KJ3, Is Real Item: False
# Rank 676: Score = 78.51, Item ID = B09MG87ZLK, Is Real Item: False
# Rank 677: Score = 78.51, Item ID = B09P8S38KR, Is Real Item: False
# Rank 678: Score = 78.51, Item ID = B07QJ97BHQ, Is Real Item: False
# Rank 679: Score = 78.50, Item ID = B0BFKCJLS5, Is Real Item: False
# Rank 680: Score = 78.50, Item ID = B08LMNMMS4, Is Real Item: False
# Rank 681: Score = 78.50, Item ID = B0C1C2P853, Is Real Item: False
# Rank 682: Score = 78.50, Item ID = B09L9W4HJB, Is Real Item: False
# Rank 683: Score = 78.50, Item ID = B0C5Y1C7JN, Is Real Item: False
# Rank 684: Score = 78.50, Item ID = B07NWDKX2N, Is Real Item: False
# Rank 685: Score = 78.50, Item ID = B09D7CHMFQ, Is Real Item: False
# Rank 686: Score = 78.50, Item ID = B0B1WQFFWF, Is Real Item: False
# Rank 687: Score = 78.50, Item ID = B0BG7ZDJGK, Is Real Item: False
# Rank 688: Score = 78.50, Item ID = B00MTAGICI, Is Real Item: False
# Rank 689: Score = 78.50, Item ID = B0C73CY9XC, Is Real Item: False
# Rank 690: Score = 78.50, Item ID = B0BV2YZ7FV, Is Real Item: False
# Rank 691: Score = 78.50, Item ID = B0B979DSKM, Is Real Item: False
# Rank 692: Score = 78.49, Item ID = B083414J18, Is Real Item: False
# Rank 693: Score = 78.49, Item ID = B071YBZVTL, Is Real Item: False
# Rank 694: Score = 78.49, Item ID = B00VSO3AFO, Is Real Item: False
# Rank 695: Score = 78.49, Item ID = B0C4H5528W, Is Real Item: False
# Rank 696: Score = 78.49, Item ID = B0B3XMH1F2, Is Real Item: False
# Rank 697: Score = 78.48, Item ID = B0C3LQ7S9L, Is Real Item: False
# Rank 698: Score = 78.48, Item ID = B0BGYYS9N4, Is Real Item: False
# Rank 699: Score = 78.48, Item ID = B00CXXSIJM, Is Real Item: False
# Rank 700: Score = 78.48, Item ID = B091DSKBGV, Is Real Item: False
# Rank 701: Score = 78.48, Item ID = B08GZ7LCMN, Is Real Item: False
# Rank 702: Score = 78.48, Item ID = B0BLVHK4YS, Is Real Item: False
# Rank 703: Score = 78.48, Item ID = B09WDTNPTW, Is Real Item: False
# Rank 704: Score = 78.47, Item ID = B0B7X1CF5Q, Is Real Item: False
# Rank 705: Score = 78.47, Item ID = B0BQHMKX9S, Is Real Item: False
# Rank 706: Score = 78.47, Item ID = B0BD876MQT, Is Real Item: False
# Rank 707: Score = 78.47, Item ID = B0BYHCYTNK, Is Real Item: False
# Rank 708: Score = 78.47, Item ID = B0BFQ5NMVW, Is Real Item: False
# Rank 709: Score = 78.47, Item ID = B09BH738J6, Is Real Item: False
# Rank 710: Score = 78.47, Item ID = B087T3PRX8, Is Real Item: False
# Rank 711: Score = 78.47, Item ID = B00QZH82BQ, Is Real Item: False
# Rank 712: Score = 78.46, Item ID = B09QVDCS3B, Is Real Item: False
# Rank 713: Score = 78.46, Item ID = B096W66H67, Is Real Item: False
# Rank 714: Score = 78.46, Item ID = B0BTDPQVXV, Is Real Item: False
# Rank 715: Score = 78.46, Item ID = B0BNK5W7TF, Is Real Item: False
# Rank 716: Score = 78.46, Item ID = B08R1F4PNX, Is Real Item: False
# Rank 717: Score = 78.46, Item ID = B09XBDHLHY, Is Real Item: False
# ...
# Rank 763: Score = 78.39, Item ID = B078GK73TK, Is Real Item: False
# Rank 764: Score = 78.38, Item ID = B0BSDKTV94, Is Real Item: False
# Rank 765: Score = 78.38, Item ID = B09YVK7J45, Is Real Item: False
# Rank 766: Score = 78.38, Item ID = B07TCLC2R6, Is Real Item: False
# Rank 767: Score = 78.38, Item ID = B0BN8K4P7P, Is Real Item: False
# Rank 768: Score = 78.38, Item ID = B07V58Q1JL, Is Real Item: False
# Rank 769: Score = 78.37, Item ID = B08NXG7FN4, Is Real Item: False
# Rank 770: Score = 78.37, Item ID = B0834JP97K, Is Real Item: False
# Rank 771: Score = 78.37, Item ID = B083973R7X, Is Real Item: False
# Rank 772: Score = 78.37, Item ID = B0BFWXJ525, Is Real Item: False
# Rank 773: Score = 78.37, Item ID = B09XWWB725, Is Real Item: False
# Rank 774: Score = 78.37, Item ID = B09F8SMW6Q, Is Real Item: False
# Rank 775: Score = 78.36, Item ID = B07CW55T4L, Is Real Item: False
# Rank 776: Score = 78.36, Item ID = B09LVF3LNX, Is Real Item: False
# Rank 777: Score = 78.36, Item ID = B0148O64JE, Is Real Item: False
# Rank 778: Score = 78.36, Item ID = B086VN65CL, Is Real Item: False
# Rank 779: Score = 78.36, Item ID = B07YDB31G4, Is Real Item: False
# Rank 780: Score = 78.36, Item ID = B09Z6S1JF6, Is Real Item: False
# Rank 781: Score = 78.36, Item ID = B09HTRNG1T, Is Real Item: False
# Rank 782: Score = 78.35, Item ID = B07QBFTP8C, Is Real Item: False
# Rank 783: Score = 78.35, Item ID = B079P1Y5W8, Is Real Item: False
# Rank 784: Score = 78.35, Item ID = B0BW3Y9BCB, Is Real Item: False
# Rank 785: Score = 78.35, Item ID = B09XBBB9SM, Is Real Item: False
# Rank 786: Score = 78.34, Item ID = B0B2RNGPWR, Is Real Item: False
# Rank 787: Score = 78.34, Item ID = B01HQFVIZC, Is Real Item: False
# Rank 788: Score = 78.34, Item ID = B0C6R6BP58, Is Real Item: False
# Rank 789: Score = 78.34, Item ID = B09159VC3W, Is Real Item: False
# Rank 790: Score = 78.34, Item ID = B0CBHH1FVK, Is Real Item: False
# Rank 791: Score = 78.34, Item ID = B08V56W7P2, Is Real Item: False
# Rank 792: Score = 78.33, Item ID = B0BY8ZDV11, Is Real Item: False
# Rank 793: Score = 78.33, Item ID = B0BKKRGFC6, Is Real Item: False
# Rank 794: Score = 78.33, Item ID = B0BXGJWTJR, Is Real Item: False
# Rank 795: Score = 78.32, Item ID = B09JNPNZC9, Is Real Item: False
# Rank 796: Score = 78.32, Item ID = B08YJR63XJ, Is Real Item: False
# Rank 797: Score = 78.32, Item ID = B08XPG8FR5, Is Real Item: False
# Rank 798: Score = 78.32, Item ID = B0C72Z4RKF, Is Real Item: False
# Rank 799: Score = 78.32, Item ID = B0BQYJYB8H, Is Real Item: False
# Rank 800: Score = 78.32, Item ID = B08JCQCTT8, Is Real Item: False
# Rank 801: Score = 78.31, Item ID = B07D8TLQ6L, Is Real Item: False
# Rank 802: Score = 78.31, Item ID = B00LD1FCFS, Is Real Item: False
# Rank 803: Score = 78.31, Item ID = B0BFPLY15W, Is Real Item: False
# Rank 804: Score = 78.31, Item ID = B0B1J74326, Is Real Item: False
# Rank 805: Score = 78.31, Item ID = B0BPC8J5XX, Is Real Item: False
# Rank 806: Score = 78.31, Item ID = B072317XNY, Is Real Item: False
# Rank 807: Score = 78.30, Item ID = B08RBJ4V7Y, Is Real Item: False
# Rank 808: Score = 78.30, Item ID = B07ZQZD6WX, Is Real Item: False
# Rank 809: Score = 78.30, Item ID = B0BHVCF9ND, Is Real Item: False
# Rank 810: Score = 78.30, Item ID = B0C23QY915, Is Real Item: False
# Rank 811: Score = 78.30, Item ID = B088LXR8PW, Is Real Item: False
# Rank 812: Score = 78.30, Item ID = B000IXRMSM, Is Real Item: False
# Rank 813: Score = 78.30, Item ID = B09MFHSJR6, Is Real Item: False
# Rank 814: Score = 78.30, Item ID = B000923524, Is Real Item: False
# Rank 815: Score = 78.29, Item ID = B09RGLZNX9, Is Real Item: False
# Rank 816: Score = 78.29, Item ID = B08CP9H8K1, Is Real Item: False
# Rank 817: Score = 78.29, Item ID = B0C5XGD8JL, Is Real Item: False
# Rank 818: Score = 78.29, Item ID = B09B51TCKS, Is Real Item: False
# Rank 819: Score = 78.29, Item ID = B09YH64N6L, Is Real Item: False
# Rank 820: Score = 78.29, Item ID = B09DRN3R5Y, Is Real Item: False
# Rank 821: Score = 78.28, Item ID = B09ZVDCLZK, Is Real Item: False
# Rank 822: Score = 78.28, Item ID = B07GYSNM7G, Is Real Item: False
# Rank 823: Score = 78.28, Item ID = B07W534ZFS, Is Real Item: False
# Rank 824: Score = 78.28, Item ID = B007C68PNY, Is Real Item: False
# Rank 825: Score = 78.28, Item ID = B08N18BD1R, Is Real Item: False
# Rank 826: Score = 78.28, Item ID = B07GFTNRMN, Is Real Item: False
# Rank 827: Score = 78.28, Item ID = B09PDTJ6B2, Is Real Item: False
# Rank 828: Score = 78.28, Item ID = B09NVWQ2TW, Is Real Item: False
# Rank 829: Score = 78.28, Item ID = B0BKTPLC9G, Is Real Item: False
# Rank 830: Score = 78.28, Item ID = B0BK874VSS, Is Real Item: False
# Rank 831: Score = 78.28, Item ID = B0BWM7961P, Is Real Item: False
# Rank 832: Score = 78.28, Item ID = B08QTSSGTB, Is Real Item: False
# Rank 833: Score = 78.27, Item ID = B0BRKPTYH9, Is Real Item: False
# Rank 834: Score = 78.27, Item ID = B0971W5GJK, Is Real Item: False
# Rank 835: Score = 78.27, Item ID = B0B4HGGPYH, Is Real Item: False
# Rank 836: Score = 78.27, Item ID = B091DCDBQ9, Is Real Item: False
# Rank 837: Score = 78.27, Item ID = B0BXRSH23P, Is Real Item: False
# Rank 838: Score = 78.27, Item ID = B09LRYBVXJ, Is Real Item: False
# Rank 839: Score = 78.27, Item ID = B09N9ZN578, Is Real Item: False
# Rank 840: Score = 78.27, Item ID = B09V2WJSVN, Is Real Item: False
# Rank 841: Score = 78.26, Item ID = B0BQHHMDHF, Is Real Item: False
# Rank 842: Score = 78.26, Item ID = B07ND2YYMM, Is Real Item: False
# Rank 843: Score = 78.26, Item ID = B09KH9G3N8, Is Real Item: False
# Rank 844: Score = 78.26, Item ID = B0BRSG7ZZW, Is Real Item: False
# Rank 845: Score = 78.26, Item ID = B09CTND5WW, Is Real Item: False
# Rank 846: Score = 78.26, Item ID = B0BB9NCZHD, Is Real Item: False
# Rank 847: Score = 78.25, Item ID = B0BWFCR613, Is Real Item: False
# Rank 848: Score = 78.25, Item ID = B07C9HXG5J, Is Real Item: False
# Rank 849: Score = 78.25, Item ID = B09D5PC4HZ, Is Real Item: False
# Rank 850: Score = 78.25, Item ID = B0BHC8WDHN, Is Real Item: False
# Rank 851: Score = 78.25, Item ID = B09DMX6TZS, Is Real Item: False
# Rank 852: Score = 78.24, Item ID = B0BDLKK1Z7, Is Real Item: False
# Rank 853: Score = 78.24, Item ID = B0C5VSBNJT, Is Real Item: False
# Rank 854: Score = 78.24, Item ID = B09Y2Z5WBY, Is Real Item: False
# Rank 855: Score = 78.23, Item ID = B09MM6Q7H2, Is Real Item: False
# Rank 856: Score = 78.23, Item ID = B091P9QXX7, Is Real Item: False
# Rank 857: Score = 78.23, Item ID = B09Y8YJ9LF, Is Real Item: False
# Rank 858: Score = 78.23, Item ID = B0BT3394C1, Is Real Item: False
# Rank 859: Score = 78.22, Item ID = B0BXRZBQBN, Is Real Item: False
# Rank 860: Score = 78.22, Item ID = B0C4Z7KMKM, Is Real Item: False
# Rank 861: Score = 78.22, Item ID = B003AVZEZW, Is Real Item: False
# Rank 862: Score = 78.22, Item ID = B0BLMN556B, Is Real Item: False
# Rank 863: Score = 78.22, Item ID = B0BDL2X48F, Is Real Item: False
# Rank 864: Score = 78.21, Item ID = B07F946Z1V, Is Real Item: False
# Rank 865: Score = 78.21, Item ID = B09V5B58QV, Is Real Item: False
# Rank 866: Score = 78.21, Item ID = B0882RV2JT, Is Real Item: False
# Rank 867: Score = 78.21, Item ID = B009L1MXE0, Is Real Item: False
# Rank 868: Score = 78.21, Item ID = B09W2FMZJZ, Is Real Item: False
# Rank 869: Score = 78.21, Item ID = B09NCYKKWY, Is Real Item: False
# Rank 870: Score = 78.20, Item ID = B0BSJFXT16, Is Real Item: False
# Rank 871: Score = 78.20, Item ID = B0BBMTHNV1, Is Real Item: False
# Rank 872: Score = 78.20, Item ID = B0C27BTNZR, Is Real Item: False
# Rank 873: Score = 78.20, Item ID = B07RN9WKW2, Is Real Item: False
# Rank 874: Score = 78.20, Item ID = B09KN77D8H, Is Real Item: False
# Rank 875: Score = 78.20, Item ID = B09KN84GJ9, Is Real Item: False
# Rank 876: Score = 78.20, Item ID = B09TNZL269, Is Real Item: False
# Rank 877: Score = 78.20, Item ID = B09XM3QVLL, Is Real Item: False
# Rank 878: Score = 78.19, Item ID = B0BBQ9JWLB, Is Real Item: False
# Rank 879: Score = 78.19, Item ID = B0C8BYB6NW, Is Real Item: False
# Rank 880: Score = 78.19, Item ID = B08Y64GH41, Is Real Item: False
# Rank 881: Score = 78.19, Item ID = B0BFBQZZMC, Is Real Item: False
# Rank 882: Score = 78.19, Item ID = B09NHS416V, Is Real Item: False
# Rank 883: Score = 78.19, Item ID = B09422G6DG, Is Real Item: False
# Rank 884: Score = 78.19, Item ID = B01ELUGNQE, Is Real Item: False
# Rank 885: Score = 78.19, Item ID = B09JRHBYYB, Is Real Item: False
# Rank 886: Score = 78.19, Item ID = B0B79MGHCK, Is Real Item: False
# Rank 887: Score = 78.19, Item ID = B0B79MGHCK, Is Real Item: False
# Rank 888: Score = 78.19, Item ID = B07W5YGZ72, Is Real Item: False
# Rank 889: Score = 78.18, Item ID = B09TL8N4MD, Is Real Item: False
# Rank 890: Score = 78.18, Item ID = B0C7HLF9YP, Is Real Item: False
# Rank 891: Score = 78.18, Item ID = B075D6LHTT, Is Real Item: False
# Rank 892: Score = 78.18, Item ID = B07FYJVFNK, Is Real Item: False
# Rank 893: Score = 78.18, Item ID = B0B3S88X6X, Is Real Item: False
# Rank 894: Score = 78.18, Item ID = B0C1RWBDW8, Is Real Item: False
# Rank 895: Score = 78.18, Item ID = B091YFGFSY, Is Real Item: False
# Rank 896: Score = 78.17, Item ID = B091CTF4T8, Is Real Item: False
# Rank 897: Score = 78.17, Item ID = B0C1RSHZW8, Is Real Item: False
# Rank 898: Score = 78.17, Item ID = B08R5JJB74, Is Real Item: False
# Rank 899: Score = 78.17, Item ID = B08R5JJB74, Is Real Item: False
# Rank 900: Score = 78.17, Item ID = B09WVG38YF, Is Real Item: False
# Rank 901: Score = 78.17, Item ID = B0B8Y53H88, Is Real Item: False
# Rank 902: Score = 78.17, Item ID = B09S2BTDKD, Is Real Item: False
# Rank 903: Score = 78.17, Item ID = B0BD827XJ8, Is Real Item: False
# Rank 904: Score = 78.17, Item ID = B09VXB6YDJ, Is Real Item: False
# Rank 905: Score = 78.17, Item ID = B08ZXNLCL9, Is Real Item: False
# Rank 906: Score = 78.16, Item ID = B081GNK55B, Is Real Item: False
# Rank 907: Score = 78.16, Item ID = B01GFVQM36, Is Real Item: False
# Rank 908: Score = 78.16, Item ID = B095T2YQ4D, Is Real Item: False
# Rank 909: Score = 78.16, Item ID = B0C61JT7T2, Is Real Item: False
# Rank 910: Score = 78.16, Item ID = B0BP6NNCVF, Is Real Item: False
# Rank 911: Score = 78.15, Item ID = B0BBL4V8B3, Is Real Item: False
# Rank 912: Score = 78.15, Item ID = B0C5XDB8HJ, Is Real Item: False
# Rank 913: Score = 78.15, Item ID = B0C5XDB8HJ, Is Real Item: False
# Rank 914: Score = 78.15, Item ID = B0B6VTVSPD, Is Real Item: False
# Rank 915: Score = 78.15, Item ID = B07YCTPKMP, Is Real Item: False
# Rank 916: Score = 78.15, Item ID = B07Z67MMGC, Is Real Item: False
# Rank 917: Score = 78.15, Item ID = B09YJPWY8V, Is Real Item: False
# Rank 918: Score = 78.15, Item ID = B09CPPX259, Is Real Item: False
# Rank 919: Score = 78.15, Item ID = B0C7NFP8RJ, Is Real Item: False
# Rank 920: Score = 78.14, Item ID = B07VQ9R7SM, Is Real Item: False
# Rank 921: Score = 78.14, Item ID = B08FM2SFLG, Is Real Item: False
# Rank 922: Score = 78.14, Item ID = B08C7NGJF1, Is Real Item: False
# Rank 923: Score = 78.14, Item ID = B003DWE3OQ, Is Real Item: False
# Rank 924: Score = 78.14, Item ID = B08Y6BWBJN, Is Real Item: False
# Rank 925: Score = 78.14, Item ID = B0BGDHCYX3, Is Real Item: False
# Rank 926: Score = 78.14, Item ID = B0C6GRYG6S, Is Real Item: False
# Rank 927: Score = 78.14, Item ID = B0BBMZ9528, Is Real Item: False
# Rank 928: Score = 78.14, Item ID = B0C2Z12XBN, Is Real Item: False
# Rank 929: Score = 78.14, Item ID = B0BN1X5R65, Is Real Item: False
# Rank 930: Score = 78.13, Item ID = B0BZ6L12W9, Is Real Item: False
# Rank 931: Score = 78.13, Item ID = B0BH3FBGGM, Is Real Item: False
# Rank 932: Score = 78.13, Item ID = B091KW1VQ8, Is Real Item: False
# Rank 933: Score = 78.13, Item ID = B07DD68D4Q, Is Real Item: False
# Rank 934: Score = 78.13, Item ID = B096RPC8X2, Is Real Item: False
# Rank 935: Score = 78.13, Item ID = B0B49L58J4, Is Real Item: False
# Rank 936: Score = 78.13, Item ID = B0BC6BKXH3, Is Real Item: False
# Rank 937: Score = 78.13, Item ID = B0C11PF68H, Is Real Item: False
# Rank 938: Score = 78.13, Item ID = B09TXW49H6, Is Real Item: False
# Rank 939: Score = 78.12, Item ID = B09VDCQJ8X, Is Real Item: False
# Rank 940: Score = 78.12, Item ID = B0BLGY3MT2, Is Real Item: False
# Rank 941: Score = 78.12, Item ID = B08HK3CJSQ, Is Real Item: False
# Rank 942: Score = 78.12, Item ID = B08HK3CJSQ, Is Real Item: False
# Rank 943: Score = 78.12, Item ID = B08HK3CJSQ, Is Real Item: False
# Rank 944: Score = 78.12, Item ID = B08W3RX484, Is Real Item: False
# Rank 945: Score = 78.12, Item ID = B09FW16C26, Is Real Item: False
# Rank 946: Score = 78.12, Item ID = B0BY68Z3L1, Is Real Item: False
# Rank 947: Score = 78.12, Item ID = B08Z32TCKH, Is Real Item: False
# Rank 948: Score = 78.12, Item ID = B0C1JBCYYD, Is Real Item: False
# Rank 949: Score = 78.11, Item ID = B0B3RN1255, Is Real Item: False
# Rank 950: Score = 78.11, Item ID = B091CBQHYV, Is Real Item: False
# Rank 951: Score = 78.11, Item ID = B0BKPP37FV, Is Real Item: False
# Rank 952: Score = 78.11, Item ID = B0C5FMTQ7N, Is Real Item: False
# Rank 953: Score = 78.11, Item ID = B08CB1XYM1, Is Real Item: False
# Rank 954: Score = 78.11, Item ID = B09FJQH2KV, Is Real Item: False
# Rank 955: Score = 78.11, Item ID = B00P2XZBD6, Is Real Item: False
# Rank 956: Score = 78.11, Item ID = B00P2XZBD6, Is Real Item: False
# Rank 957: Score = 78.11, Item ID = B01K48VZ24, Is Real Item: False
# Rank 958: Score = 78.10, Item ID = B01C4YTI1Q, Is Real Item: False
# Rank 959: Score = 78.10, Item ID = B0BGKHK1T8, Is Real Item: False
# Rank 960: Score = 78.10, Item ID = B08PKRPDJ6, Is Real Item: False
# Rank 961: Score = 78.10, Item ID = B07MQLDJLW, Is Real Item: False
# Rank 962: Score = 78.10, Item ID = B0BD82WZ7Z, Is Real Item: False
# Rank 963: Score = 78.10, Item ID = B01IFQ0TY2, Is Real Item: False
# Rank 964: Score = 78.10, Item ID = B0BXKWM5J7, Is Real Item: False
# Rank 965: Score = 78.09, Item ID = B09R9Q1RC1, Is Real Item: False
# Rank 966: Score = 78.09, Item ID = B08NVS6PSK, Is Real Item: False
# Rank 967: Score = 78.09, Item ID = B07SHZQ4R1, Is Real Item: False
# Rank 968: Score = 78.09, Item ID = B0BZ7Y5VL5, Is Real Item: False
# Rank 969: Score = 78.09, Item ID = B09CPYDXRC, Is Real Item: False
# Rank 970: Score = 78.09, Item ID = B0B7L3NS54, Is Real Item: False
# Rank 971: Score = 78.09, Item ID = B0C22WT694, Is Real Item: False
# Rank 972: Score = 78.09, Item ID = B07N7DJS85, Is Real Item: False
# Rank 973: Score = 78.09, Item ID = B0BDZ1NTF3, Is Real Item: False
# Rank 974: Score = 78.08, Item ID = B0C6JWRLYK, Is Real Item: False
# Rank 975: Score = 78.08, Item ID = B0BZ87VN3R, Is Real Item: False
# Rank 976: Score = 78.08, Item ID = B09DVPQQWW, Is Real Item: False
# Rank 977: Score = 78.08, Item ID = B0BGM46555, Is Real Item: False
# Rank 978: Score = 78.08, Item ID = B08T7G1421, Is Real Item: False
# Rank 979: Score = 78.08, Item ID = B0BZYRBXBS, Is Real Item: False
# Rank 980: Score = 78.08, Item ID = B07PY61N2W, Is Real Item: False
# Rank 981: Score = 78.07, Item ID = B09XL9MSKV, Is Real Item: False
# Rank 982: Score = 78.07, Item ID = B097P664V2, Is Real Item: False
# Rank 983: Score = 78.07, Item ID = B0C2TXTKKX, Is Real Item: False
# Rank 984: Score = 78.07, Item ID = B0BY81SMVD, Is Real Item: False
# Rank 985: Score = 78.07, Item ID = B0BHQL218H, Is Real Item: False
# Rank 986: Score = 78.07, Item ID = B07SW1RHRP, Is Real Item: False
# Rank 987: Score = 78.07, Item ID = B0CF5CTZ1T, Is Real Item: False
# Rank 988: Score = 78.07, Item ID = B0BDMVQ5SC, Is Real Item: False
# Rank 989: Score = 78.07, Item ID = B0BTV9CRFS, Is Real Item: False
# Rank 990: Score = 78.07, Item ID = B0BKZPKK7J, Is Real Item: False
# Rank 991: Score = 78.07, Item ID = B08YJCQ23B, Is Real Item: False
# Rank 992: Score = 78.06, Item ID = B09VMB3ZXF, Is Real Item: False
# Rank 993: Score = 78.06, Item ID = B08QRNRGFH, Is Real Item: False
# Rank 994: Score = 78.06, Item ID = B08SMM8XCJ, Is Real Item: False
# Rank 995: Score = 78.06, Item ID = B08TKL1HSN, Is Real Item: False
# Rank 996: Score = 78.06, Item ID = B0C5WTV2XH, Is Real Item: False
# Rank 997: Score = 78.06, Item ID = B0C5WTV2XH, Is Real Item: False
# Rank 998: Score = 78.05, Item ID = B09X5B29G4, Is Real Item: False
# Rank 999: Score = 78.05, Item ID = B0B12MFGYF, Is Real Item: False
# Rank 1000: Score = 78.05, Item ID = B015FVTRSO, Is Real Item: False

# %%
print(len(result_list[2]['matched_items']))
# Out:
# 4225

# %%
import torch
import torch.nn.functional as F
from tqdm import tqdm

real_item_in_top200_count = 0
total_results = min(100, len(result_list))

for result in tqdm(result_list[:100], desc="Processing Results", unit="result"):
    query = []
    passages = []
    query.append(f"query: {result['query']}")

    for matched_item in result['matched_items']:
        passages.append(f"passage: {matched_item['metadata']}")

    # Combine query and passages into input_texts
    input_texts = query + passages

    # Tokenize inputs
    batch_dict = tokenizer(
        input_texts,
        max_length=128,
        padding=True,
        truncation=True,
        return_tensors='pt'
    )
    batch_dict = {key: value.to(device) for key, value in batch_dict.items()}

    # Get embeddings
    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])
    embeddings = F.normalize(embeddings, p=2, dim=1)

    # Compute scores
    scores = (embeddings[:1] @ embeddings[1:].T) * 100  # Compute similarity scores
    scores = scores.squeeze(0)  # Remove extra dimension for easier processing

    # Get top-10 scores and corresponding indices
    top_scores, top_indices = torch.topk(scores, k=200)

    # Map top scores to matched_items and check if real_item is in top-10
    top_matched_items = [result['matched_items'][idx] for idx in top_indices]

    # Check if real_item is in top-10
    real_item_found = any(matched_item['item_id'] == result['real_item_id'] for matched_item in top_matched_items)

    # Update count if real_item is found in top-10
    if real_item_found:
        real_item_in_top200_count += 1

# Calculate the probability
if total_results > 0:
    probability = real_item_in_top200_count / total_results
else:
    probability = 0.0

print(f"\nProbability of real_item appearing in top-200: {probability:.2%}")
# Out:
# Processing Results: 100%|██████████| 100/100 [11:46<00:00,  7.06s/result]
# Probability of real_item appearing in top-200: 78.00%

# %%
# extend to all results
import torch
import torch.nn.functional as F
from tqdm import tqdm

real_item_in_top200_count = 0
total_results = len(result_list)

for result in tqdm(result_list, desc="Processing Results", unit="result"):
    query = []
    passages = []
    query.append(f"query: {result['query']}")

    for matched_item in result['matched_items']:
        passages.append(f"passage: {matched_item['metadata']}")

    # Combine query and passages into input_texts
    input_texts = query + passages

    # Tokenize inputs
    batch_dict = tokenizer(
        input_texts,
        max_length=128,
        padding=True,
        truncation=True,
        return_tensors='pt'
    )
    batch_dict = {key: value.to(device) for key, value in batch_dict.items()}

    # Get embeddings
    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])
    embeddings = F.normalize(embeddings, p=2, dim=1)

    # Compute scores
    scores = (embeddings[:1] @ embeddings[1:].T) * 100  # Compute similarity scores
    scores = scores.squeeze(0)  # Remove extra dimension for easier processing

    # Dynamically determine top-k value
    k = min(200, scores.size(0))  # Ensure k does not exceed the number of scores

    # Get top-k scores and corresponding indices
    top_scores, top_indices = torch.topk(scores, k=k)

    # Map top scores to matched_items and check if real_item is in top-k
    top_matched_items = [result['matched_items'][idx] for idx in top_indices]

    # Check if real_item is in top-k
    real_item_found = any(matched_item['item_id'] == result['real_item_id'] for matched_item in top_matched_items)

    # Update count if real_item is found in top-k
    if real_item_found:
        real_item_in_top200_count += 1

# Calculate the probability
if total_results > 0:
    probability = real_item_in_top200_count / total_results
else:
    probability = 0.0

print(f"\nProbability of real_item appearing in top-200: {probability:.2%}")

# %%
import torch
import pickle

# Save category mappings (required for inference)
mappings = {
    'category_to_idx': category_to_idx,
    'idx_to_category': idx_to_category,
    'num_categories': num_categories
}

with open('category_mappings.pkl', 'wb') as f:
    pickle.dump(mappings, f)

print("Saved category_mappings.pkl")
print(f"Total categories: {num_categories}")

# NOTE: The QueryClassifier model needs to be saved BEFORE cell 20
# because the 'model' variable gets overwritten with the E5 model.
#
# To save the QueryClassifier properly, add this cell between cell 18 and 20:
#
# # Save trained QueryClassifier
# torch.save(model.state_dict(), 'query_classifier.pth')
# classifier_model = model  # Keep a reference
# print("Saved query_classifier.pth")
#
# The E5 model doesn't need saving as it's loaded from HuggingFace

print("\n⚠️  WARNING: QueryClassifier model not saved!")
print("   Add the save code between cells 18-20 to preserve the trained model.")

# %% [markdown]
# ## Loading Saved Weights for Inference
#
# To reuse the trained model in a new session, use the following code:

# %%
# Example: How to load saved weights for inference
import torch
import pickle
from transformers import BertTokenizer, BertModel, AutoTokenizer, AutoModel
from torch import nn

# 1. Load category mappings
with open('category_mappings.pkl', 'rb') as f:
    mappings = pickle.load(f)

category_to_idx = mappings['category_to_idx']
idx_to_category = mappings['idx_to_category']
num_categories = mappings['num_categories']

print(f"Loaded {num_categories} categories")

# 2. Reconstruct QueryClassifier model architecture
class QueryClassifier(nn.Module):
    def __init__(self, num_categories):
        super(QueryClassifier, self).__init__()
        self.bert = BertModel.from_pretrained("bert-large-uncased")
        self.classifier = nn.Sequential(
            nn.Linear(self.bert.config.hidden_size, 512),
            nn.ReLU(),
            nn.Dropout(0.2),
            nn.Linear(512, num_categories)
        )

    def forward(self, input_ids, attention_mask):
        outputs = self.bert(input_ids=input_ids, attention_mask=attention_mask)
        cls_token = outputs.last_hidden_state[:, 0, :]
        logits = self.classifier(cls_token)
        return logits

# 3. Load trained weights
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
classifier = QueryClassifier(num_categories).to(device)
classifier.load_state_dict(torch.load('query_classifier.pth', map_location=device))
classifier.eval()

print("✓ QueryClassifier loaded successfully")

# 4. Load E5 model for semantic similarity
e5_tokenizer = AutoTokenizer.from_pretrained('intfloat/multilingual-e5-base')
e5_model = AutoModel.from_pretrained('intfloat/multilingual-e5-base').to(device)

print("✓ E5 model loaded successfully")
print("\nModels ready for inference!")

# %% [markdown]
# ## Optimized Version - Pre-compute Embeddings
#
# The original approach recomputes embeddings for the same items repeatedly. This optimized version pre-computes all item embeddings once, reducing runtime from ~2 hours to ~5-10 minutes.

# %%
# Step 1: Pre-compute embeddings for all unique items
import torch
import torch.nn.functional as F
from tqdm import tqdm

# Create a mapping of item_id to metadata
item_id_to_metadata = {item['item_id']: item['metadata'] for item in new_list}
unique_item_ids = list(item_id_to_metadata.keys())

print(f"Pre-computing embeddings for {len(unique_item_ids)} unique items...")

# Pre-compute embeddings in batches
item_embeddings = {}
batch_size = 128  # Adjust based on GPU memory

for i in tqdm(range(0, len(unique_item_ids), batch_size), desc="Computing item embeddings"):
    batch_ids = unique_item_ids[i:i+batch_size]
    batch_texts = [f"passage: {item_id_to_metadata[item_id]}" for item_id in batch_ids]

    # Tokenize batch
    batch_dict = tokenizer(
        batch_texts,
        max_length=128,
        padding=True,
        truncation=True,
        return_tensors='pt'
    )
    batch_dict = {key: value.to(device) for key, value in batch_dict.items()}

    # Get embeddings
    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])
        embeddings = F.normalize(embeddings, p=2, dim=1)

    # Store embeddings
    for item_id, emb in zip(batch_ids, embeddings):
        item_embeddings[item_id] = emb.cpu()  # Move to CPU to save GPU memory

print(f"✓ Pre-computed {len(item_embeddings)} item embeddings")
# Out:
# Pre-computing embeddings for 19522 unique items...
# Computing item embeddings: 100%|██████████| 153/153 [00:30<00:00,  4.94it/s]
# ✓ Pre-computed 19522 item embeddings

# %%
# Step 2: Compute query embeddings and evaluate (MUCH FASTER)
real_item_in_top200_count = 0
total_results = len(result_list)

# Process queries in batches for even more speedup
query_batch_size = 32

for batch_start in tqdm(range(0, len(result_list), query_batch_size), desc="Processing query batches"):
    batch_end = min(batch_start + query_batch_size, len(result_list))
    batch_results = result_list[batch_start:batch_end]

    # Prepare batch queries
    batch_query_texts = [f"query: {result['query']}" for result in batch_results]

    # Tokenize query batch
    query_batch_dict = tokenizer(
        batch_query_texts,
        max_length=128,
        padding=True,
        truncation=True,
        return_tensors='pt'
    )
    query_batch_dict = {key: value.to(device) for key, value in query_batch_dict.items()}

    # Get query embeddings
    with torch.no_grad():
        outputs = model(**query_batch_dict)
        query_embeddings = average_pool(outputs.last_hidden_state, query_batch_dict['attention_mask'])
        query_embeddings = F.normalize(query_embeddings, p=2, dim=1)

    # Process each query in the batch
    for idx, (result, query_emb) in enumerate(zip(batch_results, query_embeddings)):
        # Get pre-computed embeddings for matched items
        matched_item_ids = [item['item_id'] for item in result['matched_items']]

        # Stack embeddings for matched items
        matched_embeddings = torch.stack([
            item_embeddings[item_id].to(device) for item_id in matched_item_ids
        ])

        # Compute similarity scores
        scores = (query_emb.unsqueeze(0) @ matched_embeddings.T) * 100
        scores = scores.squeeze(0)

        # Get top-k
        k = min(200, scores.size(0))
        top_scores, top_indices = torch.topk(scores, k=k)

        # Check if real item is in top-k
        top_matched_items = [result['matched_items'][idx] for idx in top_indices.cpu().numpy()]
        real_item_found = any(item['item_id'] == result['real_item_id'] for item in top_matched_items)

        if real_item_found:
            real_item_in_top200_count += 1

# Calculate probability
probability = real_item_in_top200_count / total_results if total_results > 0 else 0.0
print(f"\nProbability of real_item appearing in top-200: {probability:.2%}")
print(f"Found {real_item_in_top200_count} out of {total_results} items")
# Out:
# Processing query batches: 100%|██████████| 4/4 [00:12<00:00,  3.15s/it]
# Probability of real_item appearing in top-200: 77.88%
# Found 88 out of 113 items

# %%
# Optional: Save pre-computed embeddings for future use
torch.save(item_embeddings, 'item_embeddings.pth')
print(f"✓ Saved item embeddings to item_embeddings.pth")
print(f"  File contains {len(item_embeddings)} item embeddings")

# To load later:
# item_embeddings = torch.load('item_embeddings.pth')

# %% [markdown]
# ## Additional Optimization Options
#
# If you need even more speed:
#
# 1. **Use FAISS for similarity search** (2-5x faster for large candidate sets)
#    - Pre-build FAISS index for all items
#    - GPU-accelerated approximate nearest neighbor search
#
# 2. **Reduce candidate pool size**
#    - Use top-1 category instead of top-2 (fewer candidates)
#    - Pre-filter items before computing similarities
#
# 3. **Mixed precision (FP16)**
#    - Use `torch.cuda.amp.autocast()` for faster inference
#    - Can be 2x faster on modern GPUs
#
# 4. **Batch all queries at once** (if GPU memory allows)
#    - Process all 2,025 queries in larger batches
#    - Trade memory for speed

# %% [markdown]
# ## Debugging Accuracy Differences
#
# The batched version may produce slightly different results due to padding differences. Let's verify:

# %%
# Compare embeddings from both methods for the first query
test_result = result_list[0]
test_query = f"query: {test_result['query']}"
test_items = [f"passage: {item['metadata']}" for item in test_result['matched_items'][:5]]

# Method 1: Original (tokenize together)
input_texts_together = [test_query] + test_items
batch_together = tokenizer(input_texts_together, max_length=128, padding=True, truncation=True, return_tensors='pt')
print(f"Original method - input_ids shape: {batch_together['input_ids'].shape}")
print(f"Padding length: {batch_together['input_ids'].shape[1]}")

with torch.no_grad():
    outputs = model(**{k: v.to(device) for k, v in batch_together.items()})
    emb_together = average_pool(outputs.last_hidden_state, batch_together['attention_mask'].to(device))
    emb_together = F.normalize(emb_together, p=2, dim=1)

# Method 2: Optimized (tokenize separately)
batch_query = tokenizer([test_query], max_length=128, padding=True, truncation=True, return_tensors='pt')
batch_items = tokenizer(test_items, max_length=128, padding=True, truncation=True, return_tensors='pt')

print(f"\nOptimized method - query shape: {batch_query['input_ids'].shape}")
print(f"Optimized method - items shape: {batch_items['input_ids'].shape}")

with torch.no_grad():
    q_out = model(**{k: v.to(device) for k, v in batch_query.items()})
    emb_query = average_pool(q_out.last_hidden_state, batch_query['attention_mask'].to(device))
    emb_query = F.normalize(emb_query, p=2, dim=1)

    i_out = model(**{k: v.to(device) for k, v in batch_items.items()})
    emb_items = average_pool(i_out.last_hidden_state, batch_items['attention_mask'].to(device))
    emb_items = F.normalize(emb_items, p=2, dim=1)

# Compare embeddings
print(f"\nQuery embedding difference: {torch.max(torch.abs(emb_together[0] - emb_query[0])).item():.6f}")
print(f"Item embeddings max difference: {torch.max(torch.abs(emb_together[1:] - emb_items)).item():.6f}")

# Compare scores
scores_original = (emb_together[:1] @ emb_together[1:].T) * 100
scores_optimized = (emb_query @ emb_items.T) * 100
print(f"\nScore difference: {torch.max(torch.abs(scores_original - scores_optimized)).item():.6f}")
print(f"Scores are identical: {torch.allclose(scores_original, scores_optimized, atol=1e-5)}")

# %% [markdown]
# ## Fixed Version - Guaranteed Identical Results
#
# The issue is `padding=True` uses different padding lengths per batch. Using `padding="max_length"` ensures identical results:

# %%
# Step 1: Pre-compute embeddings with FIXED padding
import torch
import torch.nn.functional as F
from tqdm import tqdm

item_id_to_metadata = {item['item_id']: item['metadata'] for item in new_list}
unique_item_ids = list(item_id_to_metadata.keys())

print(f"Pre-computing embeddings for {len(unique_item_ids)} unique items...")

item_embeddings_fixed = {}
batch_size = 128

for i in tqdm(range(0, len(unique_item_ids), batch_size), desc="Computing item embeddings"):
    batch_ids = unique_item_ids[i:i+batch_size]
    batch_texts = [f"passage: {item_id_to_metadata[item_id]}" for item_id in batch_ids]

    # Use padding="max_length" instead of padding=True
    batch_dict = tokenizer(
        batch_texts,
        max_length=128,
        padding="max_length",  # FIXED: Always pad to 128
        truncation=True,
        return_tensors='pt'
    )
    batch_dict = {key: value.to(device) for key, value in batch_dict.items()}

    with torch.no_grad():
        outputs = model(**batch_dict)
        embeddings = average_pool(outputs.last_hidden_state, batch_dict['attention_mask'])
        embeddings = F.normalize(embeddings, p=2, dim=1)

    for item_id, emb in zip(batch_ids, embeddings):
        item_embeddings_fixed[item_id] = emb.cpu()

print(f"✓ Pre-computed {len(item_embeddings_fixed)} item embeddings with fixed padding")
# Out:
# Pre-computing embeddings for 19522 unique items...
# Computing item embeddings: 100%|██████████| 153/153 [00:30<00:00,  4.94it/s]
# ✓ Pre-computed 19522 item embeddings with fixed padding

# %%
# Step 2: Evaluate with FIXED padding (should match original exactly)
real_item_in_top200_count = 0
total_results = len(result_list)
query_batch_size = 32

for batch_start in tqdm(range(0, len(result_list), query_batch_size), desc="Processing query batches"):
    batch_end = min(batch_start + query_batch_size, len(result_list))
    batch_results = result_list[batch_start:batch_end]

    batch_query_texts = [f"query: {result['query']}" for result in batch_results]

    # Use padding="max_length" instead of padding=True
    query_batch_dict = tokenizer(
        batch_query_texts,
        max_length=128,
        padding="max_length",  # FIXED: Always pad to 128
        truncation=True,
        return_tensors='pt'
    )
    query_batch_dict = {key: value.to(device) for key, value in query_batch_dict.items()}

    with torch.no_grad():
        outputs = model(**query_batch_dict)
        query_embeddings = average_pool(outputs.last_hidden_state, query_batch_dict['attention_mask'])
        query_embeddings = F.normalize(query_embeddings, p=2, dim=1)

    for result, query_emb in zip(batch_results, query_embeddings):
        matched_item_ids = [item['item_id'] for item in result['matched_items']]

        matched_embeddings = torch.stack([
            item_embeddings_fixed[item_id].to(device) for item_id in matched_item_ids
        ])

        scores = (query_emb.unsqueeze(0) @ matched_embeddings.T) * 100
        scores = scores.squeeze(0)

        k = min(200, scores.size(0))
        top_scores, top_indices = torch.topk(scores, k=k)

        top_matched_items = [result['matched_items'][i] for i in top_indices.cpu().numpy()]
        real_item_found = any(item['item_id'] == result['real_item_id'] for item in top_matched_items)

        if real_item_found:
            real_item_in_top200_count += 1

probability = real_item_in_top200_count / total_results if total_results > 0 else 0.0
print(f"\nWith FIXED padding:")
print(f"Probability of real_item appearing in top-200: {probability:.2%}")
print(f"Found {real_item_in_top200_count} out of {total_results} items")
# Out:
# Processing query batches: 100%|██████████| 4/4 [00:12<00:00,  3.21s/it]
# With FIXED padding:
# Probability of real_item appearing in top-200: 77.88%
# Found 88 out of 113 items
